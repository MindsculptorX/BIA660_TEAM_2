# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  1 15:00:40 2017

@author: He Song
"""

from bs4 import BeautifulSoup
import time
import requests

def reviews(url,type,name):
    count=0;
    restname=[]
    fw=open(name,'w') # output file
    for p in range(1,80):
        pageLink=url+'/search?find_loc=Los+Angeles,+CA&start='+str(p*10)+'&cflt=' +type# make the page url
        for i in range(5): # try 5 times
                    try:
                        #use the browser to access the url
                        response=requests.get(pageLink,headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36', })
                        html=response.content # get the html
                        break # we got the file, break the loops
                    except Exception as e:# browser.open() threw an exception, the attempt to get the response failed
                        print ('failed attempt',i)
                        time.sleep(2) # wait 2 secs
        				
        		
        if not html:continue # couldnt get the page, ignore
                
        soup = BeautifulSoup(html.decode('ascii', 'ignore'),'lxml') # parse the html 
        divget=soup.findAll('div',{'class':'media-story'})
        
        for div in divget:
            #print(review)
            #print(div)
            try:
                restaurant=div.find('a', {'class':'biz-name js-analytics-click'}) # get all the review divs
                kind=div.find('span',{'class':'category-str-list'})
                #print(restaurant)
               
                if restaurant:
                    if 'ad_business_id' not in restaurant['href']:
                        kind_s=kind.findAll('a')
                        if len(kind_s)==1:
                            
                            reviewnum=div.find('span',{'class':'review-count rating-qualifier'})
                            
                            reviewnum=reviewnum.text.replace('reviews','')
                            reviewnum=reviewnum.replace(' ','')
                           
                            if float(reviewnum)>200 and count<=50:
                                #print(kind)
                                print(reviewnum)
                                nextse=restaurant['href']
                                print(nextse)
                                sp=restaurant.find('span')
                                print(sp.text)
                                if sp.text not in restname:
                                    fw.write(str(count)+'\t'+reviewnum+'\t'+nextse+'\t'+sp.text+'\n')
                                    restname.append(sp.text)
                                    count+=1
                                print('\n')
                                    
                            elif count>50 :
                                fw.close()
                                return
            except Exception as e:
                continue

reviews('https://www.yelp.com', 'chinese', 'chinese.txt')
# Out:
# 221
#
# /biz/the-new-moon-los-angeles
# The New Moon
#
#
#
# 242
#
# /biz/northern-cafe-los-angeles
# Northern Cafe
#
#
#
# 251
#
# /biz/pauls-kitchen-los-angeles
# Pauls Kitchen
#
#
#
# 201
#
# /biz/shin-beijing-los-angeles
# Shin Beijing
#
#
#
# 396
#
# /biz/house-of-joy-chinese-restaurant-glendale
# House of Joy Chinese Restaurant
#
#
#
# 316
#
# /biz/jin-jiang-restaurant-los-angeles
# Jin Jiang Restaurant
#
#
#
# 239
#
# /biz/chyn-king-los-angeles
# Chyn King
#
#
#
# 317
#
# /biz/phoenix-inn-chinese-cuisine-los-angeles
# Phoenix Inn Chinese Cuisine
#
#
#
# 337
#
# /biz/ixlb-dimsum-eats-los-angeles-2
# ixlb DimSum Eats
#
#
#
# 255
#
# /biz/cheng-du-restaurant-los-angeles
# Cheng Du Restaurant
#
#
#
# 898
#
# /biz/won-kok-restaurant-los-angeles
# Won Kok Restaurant
#
#
#
# 316
#
# /biz/jin-jiang-restaurant-los-angeles
# Jin Jiang Restaurant
#
#
#
# 308
#
# /biz/rice-wok-studio-city
# Rice Wok
#
#
#
# 202
#
# /biz/hot-wok-north-hollywood
# Hot Wok
#
#
#
# 248
#
# /biz/little-palace-glendale
# Little Palace
#
#
#
# 273
#
# /biz/wok-on-the-wild-side-inglewood
# Wok On The Wild Side
#
#
#
# 291
#
# /biz/hop-li-seafood-restaurant-los-angeles
# Hop Li Seafood Restaurant
#
#
#
# 1677
#
# /biz/mamas-lu-dumpling-house-monterey-park-4
# Mamas Lu Dumpling House
#
#
#
# 373
#
# /biz/hop-li-seafood-restaurant-los-angeles-2
# Hop Li Seafood Restaurant
#
#
#
# 301
#
# /biz/mandarin-kitchen-los-angeles
# Mandarin Kitchen
#
#
#
# 343
#
# /biz/chinese-deli-t-and-d-north-hollywood-2
# Chinese Deli T & D
#
#
#
# 302
#
# /biz/lao-sze-chuan-glendale-5
# Lao Sze Chuan
#
#
#
# 308
#
# /biz/rice-wok-studio-city
# Rice Wok
#
#
#
# 402
#
# /biz/twin-dragon-chinese-restaurant-los-angeles
# Twin Dragon Chinese Restaurant
#
#
#
# 291
#
# /biz/hop-li-seafood-restaurant-los-angeles
# Hop Li Seafood Restaurant
#
#
#
# 248
#
# /biz/little-palace-glendale
# Little Palace
#
#
#
# 225
#
# /biz/green-tea-house-los-angeles
# Green Tea House
#
#
#
# 228
#
# /biz/ping-pong-chinese-cuisine-encino-3
# Ping Pong Chinese Cuisine
#
#
#
# 403
#
# /biz/hop-woo-bbq-and-seafood-restaurant-la-los-angeles
# Hop Woo BBQ & Seafood Restaurant - LA
#
#
#
# 225
#
# /biz/green-tea-house-los-angeles
# Green Tea House
#
#
#
# 808
#
# /biz/maos-kitchen-venice
# Maos Kitchen
#
#
#
# 228
#
# /biz/ping-pong-chinese-cuisine-encino-3
# Ping Pong Chinese Cuisine
#
#
#
# 256
#
# /biz/regent-china-inn-los-angeles
# Regent China Inn
#
#
#
# 329
#
# /biz/grandview-palace-pasadena
# Grandview Palace
#
#
#
# 533
#
# /biz/new-moon-montrose
# New Moon
#
#
#
# 256
#
# /biz/regent-china-inn-los-angeles
# Regent China Inn
#
#
#
# 286
#
# /biz/dragon-street-chinese-north-hollywood-2
# Dragon Street Chinese
#
#
#
# 292
#
# /biz/silver-palace-chinese-restaurant-whittier-3
# Silver Palace Chinese Restaurant
#
#
#
# 201
#
# /biz/healthy-wok-sherman-oaks
# Healthy Wok
#
#
#
# 466
#
# /biz/szechuan-impression-alhambra-3
# Szechuan Impression
#
#
#
# 302
#
# /biz/chinese-delight-north-hollywood
# Chinese Delight
#
#
#
# 333
#
# /biz/golden-phoenix-lakewood
# Golden Phoenix
#
#
#
# 808
#
# /biz/maos-kitchen-venice
# Maos Kitchen
#
#
#
# 466
#
# /biz/szechuan-impression-alhambra-3
# Szechuan Impression
#
#
#
# 286
#
# /biz/dragon-street-chinese-north-hollywood-2
# Dragon Street Chinese
#
#
#
# 533
#
# /biz/new-moon-montrose
# New Moon
#
#
#
# 339
#
# /biz/chin-chin-beverly-hills
# Chin Chin
#
#
#
# 415
#
# /biz/ws-china-bistro-redondo-beach
# Ws China Bistro
#
#
#
# 235
#
# /biz/golden-hunan-chinese-restaurant-northridge
# Golden Hunan Chinese Restaurant
#
#
#
# 367
#
# /biz/hui-tou-xiang-san-gabriel
# Hui Tou Xiang
#
#
#
# 282
#
# /biz/jj-chinese-express-long-beach
# JJ Chinese Express
#
#
#
# 220
#
# /biz/wacky-wok-venice
# Wacky Wok
#
#
#
# 367
#
# /biz/hui-tou-xiang-san-gabriel
# Hui Tou Xiang
#
#
#
# 267
#
# /biz/hong-kong-express-westminster-3
# Hong Kong Express
#
#
#
# 808
#
# /biz/maos-kitchen-venice
# Maos Kitchen
#
#
#
# 659
#
# /biz/chengdu-taste-alhambra
# Chengdu Taste
#
#
#
# 371
#
# /biz/golden-wall-la-mirada
# Golden Wall
#
#
#
# 301
#
# /biz/yang-chow-pasadena
# Yang Chow
#
#
#
# 234
#
# /biz/tasty-kitchen-gardena
# Tasty Kitchen
#
#
#
# 492
#
# /biz/seafood-port-chinese-restaurant-torrance
# Seafood Port Chinese Restaurant
#
#
#
# 292
#
# /biz/silver-palace-chinese-restaurant-whittier-3
# Silver Palace Chinese Restaurant
#
#
#
# 415
#
# /biz/ws-china-bistro-redondo-beach
# Ws China Bistro
#
#
#
# 333
#
# /biz/golden-phoenix-lakewood
# Golden Phoenix
#
#
#
# 232
#
# /biz/harlams-kitchen-rosemead-2
# Harlams Kitchen
#
#
#
# 373
#
# /biz/seafood-town-chinese-restaurant-torrance
# Seafood Town Chinese Restaurant
#
#
#
# 599
#
# /biz/fortune-cookies-restaurant-los-alamitos
# Fortune Cookies Restaurant
#
#
#
# 262
#
# /biz/the-great-wall-chinese-restaurant-reseda
# The Great Wall Chinese Restaurant
#
#
#
# 220
#
# /biz/wacky-wok-venice
# Wacky Wok
#
#
#
# 211
#
# /biz/phoenix-food-boutique-south-pasadena
# Phoenix Food Boutique
#
#
# ['0\t\n', '221\n', '\t/biz/the-new-moon-los-angeles\tThe New Moon\n', '1\t\n', '242\n', '\t/biz/northern-cafe-los-angeles\tNorthern Cafe\n', '2\t\n', '251\n', '\t/biz/pauls-kitchen-los-angeles\tPauls Kitchen\n', '3\t\n', '201\n', '\t/biz/shin-beijing-los-angeles\tShin Beijing\n', '4\t\n', '396\n', '\t/biz/house-of-joy-chinese-restaurant-glendale\tHouse of Joy Chinese Restaurant\n', '5\t\n', '316\n', '\t/biz/jin-jiang-restaurant-los-angeles\tJin Jiang Restaurant\n', '6\t\n', '239\n', '\t/biz/chyn-king-los-angeles\tChyn King\n', '7\t\n', '317\n', '\t/biz/phoenix-inn-chinese-cuisine-los-angeles\tPhoenix Inn Chinese Cuisine\n', '8\t\n', '337\n', '\t/biz/ixlb-dimsum-eats-los-angeles-2\tixlb DimSum Eats\n', '9\t\n', '255\n', '\t/biz/cheng-du-restaurant-los-angeles\tCheng Du Restaurant\n', '10\t\n', '898\n', '\t/biz/won-kok-restaurant-los-angeles\tWon Kok Restaurant\n', '11\t\n', '308\n', '\t/biz/rice-wok-studio-city\tRice Wok\n', '12\t\n', '202\n', '\t/biz/hot-wok-north-hollywood\tHot Wok\n', '13\t\n', '248\n', '\t/biz/little-palace-glendale\tLittle Palace\n', '14\t\n', '273\n', '\t/biz/wok-on-the-wild-side-inglewood\tWok On The Wild Side\n', '15\t\n', '291\n', '\t/biz/hop-li-seafood-restaurant-los-angeles\tHop Li Seafood Restaurant\n', '16\t\n', '1677\n', '\t/biz/mamas-lu-dumpling-house-monterey-park-4\tMamas Lu Dumpling House\n', '17\t\n', '301\n', '\t/biz/mandarin-kitchen-los-angeles\tMandarin Kitchen\n', '18\t\n', '343\n', '\t/biz/chinese-deli-t-and-d-north-hollywood-2\tChinese Deli T & D\n', '19\t\n', '302\n', '\t/biz/lao-sze-chuan-glendale-5\tLao Sze Chuan\n', '20\t\n', '402\n', '\t/biz/twin-dragon-chinese-restaurant-los-angeles\tTwin Dragon Chinese Restaurant\n', '21\t\n', '225\n', '\t/biz/green-tea-house-los-angeles\tGreen Tea House\n', '22\t\n', '228\n', '\t/biz/ping-pong-chinese-cuisine-encino-3\tPing Pong Chinese Cuisine\n', '23\t\n', '403\n', '\t/biz/hop-woo-bbq-and-seafood-restaurant-la-los-angeles\tHop Woo BBQ & Seafood Restaurant - LA\n', '24\t\n', '808\n', '\t/biz/maos-kitchen-venice\tMaos Kitchen\n', '25\t\n', '256\n', '\t/biz/regent-china-inn-los-angeles\tRegent China Inn\n', '26\t\n', '329\n', '\t/biz/grandview-palace-pasadena\tGrandview Palace\n', '27\t\n', '533\n', '\t/biz/new-moon-montrose\tNew Moon\n', '28\t\n', '286\n', '\t/biz/dragon-street-chinese-north-hollywood-2\tDragon Street Chinese\n', '29\t\n', '292\n', '\t/biz/silver-palace-chinese-restaurant-whittier-3\tSilver Palace Chinese Restaurant\n', '30\t\n', '201\n', '\t/biz/healthy-wok-sherman-oaks\tHealthy Wok\n', '31\t\n', '466\n', '\t/biz/szechuan-impression-alhambra-3\tSzechuan Impression\n', '32\t\n', '302\n', '\t/biz/chinese-delight-north-hollywood\tChinese Delight\n', '33\t\n', '333\n', '\t/biz/golden-phoenix-lakewood\tGolden Phoenix\n', '34\t\n', '339\n', '\t/biz/chin-chin-beverly-hills\tChin Chin\n', '35\t\n', '415\n', '\t/biz/ws-china-bistro-redondo-beach\tWs China Bistro\n', '36\t\n', '235\n', '\t/biz/golden-hunan-chinese-restaurant-northridge\tGolden Hunan Chinese Restaurant\n', '37\t\n', '367\n', '\t/biz/hui-tou-xiang-san-gabriel\tHui Tou Xiang\n', '38\t\n', '282\n', '\t/biz/jj-chinese-express-long-beach\tJJ Chinese Express\n', '39\t\n', '220\n', '\t/biz/wacky-wok-venice\tWacky Wok\n', '40\t\n', '267\n', '\t/biz/hong-kong-express-westminster-3\tHong Kong Express\n', '41\t\n', '659\n', '\t/biz/chengdu-taste-alhambra\tChengdu Taste\n', '42\t\n', '371\n', '\t/biz/golden-wall-la-mirada\tGolden Wall\n', '43\t\n', '301\n', '\t/biz/yang-chow-pasadena\tYang Chow\n', '44\t\n', '234\n', '\t/biz/tasty-kitchen-gardena\tTasty Kitchen\n', '45\t\n', '492\n', '\t/biz/seafood-port-chinese-restaurant-torrance\tSeafood Port Chinese Restaurant\n', '46\t\n', '232\n', '\t/biz/harlams-kitchen-rosemead-2\tHarlams Kitchen\n', '47\t\n', '373\n', '\t/biz/seafood-town-chinese-restaurant-torrance\tSeafood Town Chinese Restaurant\n', '48\t\n', '599\n', '\t/biz/fortune-cookies-restaurant-los-alamitos\tFortune Cookies Restaurant\n', '49\t\n', '262\n', '\t/biz/the-great-wall- ...

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  1 15:00:40 2017

@author: Y. Zhao
"""

import time
import requests
import os, shutil

def getReviews(urlBase, url, filepath, maxReviews = 300):
    for p in range(0, int(maxReviews / 20)):
        pageLink=urlBase + url + '?start=' + str(p * 20) + '&sort_by=date_desc'# make the page url
        for i in range(5): # try 5 times
            try:
                #use the browser to access the url
                response=requests.get(pageLink,headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36', })
                html=response.content # get the html
                break # we got the file, break the loops
            except Exception as e:# browser.open() threw an exception, the attempt to get the response failed
                print ('failed attempt',i)
                time.sleep(2) # wait 2 secs


        if not html:
            raise Exception()
            continue # couldnt get the page, ignore
        else:
            with open(filepath + '/' + str(p) + '.html', 'w') as f:
                f.write(html.decode('ascii', 'ignore'))


#reviews('https://www.yelp.com', '/biz/lao-sze-chuan-glendale-5')

def getGene(name, maxReviews = 300):
    with open(name + '.txt', 'r') as f:
        ls = f.readlines()
        print(int(len(ls) / 3))
        for i in range(0, len(ls), 3):
            id = ls[i].strip()
            path = ls[i + 2].strip().split('\t')[0]
            print(id + " " + ls[i + 2].strip().split('\t')[1])
            if os.path.exists(os.path.join(os.getcwd(), name + "_" + id)) == False:
                try:
                    os.mkdir(os.path.join(os.getcwd(), 'temp'))
                except FileExistsError as e:
                    shutil.rmtree(os.path.join(os.getcwd(), 'temp/'))
                    os.mkdir(os.path.join(os.getcwd(), 'temp'))
                try:
                    getReviews('https://www.yelp.com', path, os.path.join(os.getcwd(), 'temp'), maxReviews = 300)
                    with open(os.path.join(os.getcwd(), 'temp') + '/metadata', 'w') as f:
                        f.write(ls[i] + ls[i + 1] + ls[i + 2] + str(int(maxReviews / 20)) + '\n')
                    os.rename(os.path.join(os.getcwd(), 'temp'), os.path.join(os.getcwd(), name + "_" + id))
                except Exception as e:
                    print ('failed attempt', name + "_" + id)
                    continue
            
getGene('chinese')
# Out:
# 51
# 0 The New Moon
# 1 Northern Cafe
# 2 Pauls Kitchen
# 3 Shin Beijing
# 4 House of Joy Chinese Restaurant
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-ca3bde57d570> in <module>()
#      57                     continue
#      58
# ---> 59 getGene('chinese')
#
# <ipython-input-6-ca3bde57d570> in getGene(name, maxReviews)
#      49                     os.mkdir(os.path.join(os.getcwd(), 'temp'))
#      50                 try:
# ---> 51                     getReviews('https://www.yelp.com', path, os.path.join(os.getcwd(), 'temp'), maxReviews = 300)
#      52                     with open(os.path.join(os.getcwd(), 'temp') + '/metadata', 'w') as f:
#      53                         f.write(ls[i] + ls[i + 1] + ls[i + 2] + str(int(maxReviews / 20)) + '\n')
#
# <ipython-input-6-ca3bde57d570> in getReviews(urlBase, url, filepath, maxReviews)
#      16             try:
#      17                 #use the browser to access the url
# ---> 18                 response=requests.get(pageLink,headers = { 'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36', })
#      19                 html=response.content # get the html
#      20                 break # we got the file, break the loops
#
# /anaconda/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# /anaconda/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# /anaconda/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# /anaconda/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# /anaconda/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# /anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda/lib/python3.5/http/client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# /anaconda/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda/lib/python3.5/socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# /anaconda/lib/python3.5/site-packages/requests/packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     275     def recv_into(self, *args, **kwargs):
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#     279             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# /anaconda/lib/python3.5/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1544             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1545         else:
# -> 1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# KeyboardInterrupt:

# %%
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  1 15:00:40 2017

@author: Yi Zhao
"""

from bs4 import BeautifulSoup
import re
import time
import requests
import pandas as pd
import os

def get1(div_review, classdesc):
    try:
        li_friends = div_review.findAll('li', {'class': classdesc})
        li_friends_b = li_friends[0].findAll('b')
        friends = li_friends_b[0].contents[0]
        return friends
    except:
        return 0


def analyseHtml(html, rId):
    results = []
    print(rId)

    soup = BeautifulSoup(html,'lxml') # parse the html 
    reviews=soup.findAll('div',{'class':'review review--with-sidebar'})
    
    for div_review in reviews:
        result = {'restaurantId': rId}
        
        review_id = div_review['data-review-id']
        result['review_id'] = review_id

        try:
            a_username = div_review.findAll('a', {'class': 'user-display-name js-analytics-click'})
            username = a_username[0].contents[0]
            result['username'] = username
        except IndexError:
            result['username'] = ''
        
        num_friends = get1(div_review, 'friend-count responsive-small-display-inline-block')
        result['num_friends'] = num_friends
        num_reviews = get1(div_review, 'review-count responsive-small-display-inline-block')
        result['num_reviews'] = num_reviews
        num_photos = get1(div_review, 'photo-count responsive-small-display-inline-block')
        result['num_photos'] = num_photos
        
        try:
            review_text = div_review.findAll('p', {'lang': 'en'})[0].contents[0]
            result['review_text'] = review_text
        except IndexError:
            result['review_text'] = ''
        
        rating_qualifier = div_review.findAll('span', {'class': 'rating-qualifier'})[0].contents[0]
        result['date'] = rating_qualifier.strip()
        
        elite = len(div_review.findAll('a', {'href': '/elite'}))
        result['elite'] = elite
        
        try:
            a_useful = div_review.findAll('class', {'ybtn ybtn--small useful js-analytics-click'})[0]
            span_useful = a_useful.findAll('span', {'class': 'count'})[0]
            useful = span_useful.contents[0]
            result['useful'] = useful
        except IndexError:
            result['useful'] = 0
        
        rating = div_review.findAll('div', {'class': 'rating-large'})[0]['title']
        result['rating'] = rating.split()[0]
    
        results.append(result)
        
    return results

def analyseDir(path, rId):
    csvfilepath = os.path.join(path, 'data.csv')
    if os.path.isfile(csvfilepath) == True:
        return pd.read_csv(csvfilepath)
    else:
        res = []
        tempfilepath = 'temp.csv'
        f = open(os.path.join(path, 'metadata'))
        pages = int(f.readlines()[3])
        for page in range(pages):
            res += analyseHtml(open(os.path.join(path, str(page) + '.html')).read(), rId)
        df2 = pd.DataFrame(res)
        df2.to_csv(tempfilepath)
        os.rename(tempfilepath, csvfilepath)
        return df2

def analyseGene(name, max_id, path='/Users/enyaning/Desktop/BIA660/BIA660_TEAM_2/'):
    dfs = []
    for id in range(max_id + 1):
        df = analyseDir(path + name + '_' + str(id), name + '_' + str(id))
        dfs.append(df)
    return pd.concat(dfs)

def main(name, max_id, path):
    df2 = analyseGene(name, max_id, path=path)
    df2.to_csv(name + '.csv')
    return df2

main('chinese', 50, '/Users/enyaning/Desktop/BIA660/BIA660_TEAM_2/')
# Out:
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_0
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_1
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_2
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# chinese_3
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-e0e72b0db7e5> in <module>()
#     105     return df2
#     106
# --> 107 main('chinese', 50, '/Users/enyaning/Desktop/BIA660/BIA660_TEAM_2/')
#
# <ipython-input-7-e0e72b0db7e5> in main(name, max_id, path)
#     101
#     102 def main(name, max_id, path):
# --> 103     df2 = analyseGene(name, max_id, path=path)
#     104     df2.to_csv(name + '.csv')
#     105     return df2
#
# <ipython-input-7-e0e72b0db7e5> in analyseGene(name, max_id, path)
#      96     dfs = []
#      97     for id in range(max_id + 1):
# ---> 98         df = analyseDir(path + name + '_' + str(id), name + '_' + str(id))
#      99         dfs.append(df)
#     100     return pd.concat(dfs)
#
# <ipython-input-7-e0e72b0db7e5> in analyseDir(path, rId)
#      84         res = []
#      85         tempfilepath = 'temp.csv'
# ---> 86         f = open(os.path.join(path, 'metadata'))
#      87         pages = int(f.readlines()[3])
#      88         for page in range(pages):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/enyaning/Desktop/BIA660/BIA660_TEAM_2/chinese_4/metadata'

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  8 14:39:07 2017

@author: enyaning
"""


import pandas as pd
import re
import operator
from nltk.corpus import stopwords

import nltk
from nltk.util import ngrams
from nltk.tokenize import sent_tokenize
from nltk import load

from textblob import TextBlob


csv_path = 'chinese.csv'
data = pd.read_csv(csv_path)

wordcount = {}
stop_words =  set(stopwords.words('english'))
costumer_stop_words = ['chinese', 'italian', 'good', 'great', 'food', 'place']
for word in costumer_stop_words: stop_words.add(word)
costumer_not_stop_words = []
for word in costumer_not_stop_words: stop_words.discard(word)

#make a new tagger
_POS_TAGGER = 'taggers/maxent_treebank_pos_tagger/english.pickle'
tagger = load(_POS_TAGGER)


jsons = []

review_number = 0
for index, row in data.iterrows():
    try:
        review = row['review_text']
        restaurantId = row['restaurantId']
        
        blob = TextBlob(review)
        blob.noun_phrases
        
        for i in range(len(blob.sentences)):
            sentence = blob.sentences[i]

            terms = nltk.word_tokenize(sentence.raw.lower())
            tagged_terms=tagger.tag(terms)
            
            for tg in ngrams(tagged_terms,2):
                if tg[0][1].startswith('NN') and tg[1][1].startswith('NN'):
                    key = tg[0][0] + " " + tg[1][0]
                    json = {
                        "restaurantId": restaurantId,
                        "review_id": index,
                        "sentence_id": i,
                        "sentence": sentence.raw,
                        "phrase": key
                    }
                    jsons.append(json)
                    
    except TypeError:
        print("TypeError");
    finally:
        if review_number%20 == 0:
            print(review_number)
        review_number += 1
        
df = pd.DataFrame(jsons)
df.to_csv('test.csv')
print(df)
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
# 420
# 440
# 460
# 480
# 500
# 520
# 540
# 560
# 580
# 600
# 620
# 640
# 660
# 680
# 700
# 720
# 740
# 760
# 780
# 800
# 820
# 840
# 860
# 880
# 900
# 920
# 940
# 960
# 980
# 1000
# 1020
# 1040
# 1060
# 1080
# 1100
# 1120
# 1140
# 1160
# 1180
# 1200
# 1220
# 1240
# 1260
# 1280
# 1300
# 1320
# 1340
# 1360
# 1380
# 1400
# 1420
# 1440
# 1460
# 1480
# 1500
# 1520
# 1540
# 1560
# 1580
# 1600
# 1620
# 1640
# 1660
# 1680
# 1700
# 1720
# 1740
# 1760
# 1780
# 1800
# 1820
# 1840
# 1860
# 1880
# 1900
# 1920
# 1940
# 1960
# 1980
# 2000
# 2020
# 2040
# 2060
# 2080
# 2100
# 2120
# 2140
# 2160
# 2180
# 2200
# 2220
# 2240
# 2260
# 2280
# 2300
# 2320
# 2340
# 2360
# 2380
# 2400
# 2420
# 2440
# 2460
# 2480
# 2500
# 2520
# 2540
# 2560
# 2580
# 2600
# 2620
# 2640
# 2660
# 2680
# 2700
# 2720
# 2740
# 2760
# 2780
# 2800
# 2820
# 2840
# 2860
# 2880
# 2900
# 2920
# 2940
# 2960
# 2980
# 3000
# 3020
# 3040
# 3060
# 3080
# 3100
# 3120
# 3140
# 3160
# 3180
# 3200
# 3220
# 3240
# 3260
# 3280
# 3300
# 3320
# 3340
# 3360
# 3380
# 3400
# 3420
# 3440
# 3460
# 3480
# 3500
# 3520
# 3540
# 3560
# 3580
# 3600
# 3620
# 3640
# 3660
# 3680
# 3700
# 3720
# 3740
# 3760
# 3780
# 3800
# 3820
# 3840
# 3860
# 3880
# 3900
# 3920
# 3940
# 3960
# 3980
# 4000
# 4020
# 4040
# 4060
# 4080
# 4100
# 4120
# 4140
# 4160
# 4180
# 4200
# 4220
# 4240
# 4260
# 4280
# 4300
# 4320
# 4340
# 4360
# 4380
# 4400
# 4420
# 4440
# 4460
# 4480
# 4500
# 4520
# 4540
# 4560
# 4580
# 4600
# 4620
# 4640
# 4660
# 4680
# 4700
# 4720
# 4740
# 4760
# 4780
# 4800
# 4820
# 4840
# 4860
# 4880
# 4900
# 4920
# 4940
# 4960
# 4980
# 5000
# 5020
# 5040
# 5060
# 5080
# 5100
# 5120
# 5140
# 5160
# 5180
# 5200
# 5220
# 5240
# 5260
# 5280
# 5300
# 5320
# 5340
# 5360
# 5380
# 5400
# 5420
# 5440
# 5460
# 5480
# 5500
# 5520
# 5540
# 5560
# 5580
# 5600
# 5620
# 5640
# 5660
# 5680
# 5700
# 5720
# 5740
# 5760
# 5780
# 5800
# 5820
# 5840
# 5860
# 5880
# 5900
# 5920
# 5940
# 5960
# 5980
# 6000
# 6020
# 6040
# 6060
# 6080
# 6100
# 6120
# 6140
# 6160
# 6180
# 6200
# 6220
# 6240
# 6260
# 6280
# 6300
# 6320
# 6340
# 6360
# 6380
# 6400
# 6420
# 6440
# 6460
# 6480
# 6500
# 6520
# 6540
# 6560
# 6580
# 6600
# 6620
# 6640
# 6660
# 6680
# 6700
# 6720
# 6740
# 6760
# 6780
# 6800
# 6820
# 6840
# 6860
# 6880
# 6900
# 6920
# 6940
# 6960
# 6980
# 7000
# 7020
# 7040
# 7060
# 7080
# 7100
# 7120
# 7140
# 7160
# 7180
# 7200
# 7220
# 7240
# 7260
# 7280
# 7300
# 7320
# 7340
# 7360
# 7380
# 7400
# 7420
# 7440
# 7460
# 7480
# 7500
# 7520
# 7540
# 7560
# 7580
# 7600
# 7620
# 7640
# 7660
# 7680
# 7700
# 7720
# 7740
# 7760
# 7780
# 7800
# 7820
# 7840
# 7860
# 7880
# 7900
# 7920
# 7940
# 7960
# 7980
# 8000
# 8020
# 8040
# 8060
# 8080
# 8100
# 8120
# 8140
# 8160
# 8180
# 8200
# 8220
# 8240
# 8260
# 8280
# 8300
# 8320
# 8340
# 8360
# 8380
# 8400
# 8420
# 8440
# 8460
# 8480
# 8500
# 8520
# 8540
# 8560
# 8580
# 8600
# 8620
# 8640
# 8660
# 8680
# 8700
# 8720
# 8740
# 8760
# 8780
# 8800
# 8820
# 8840
# 8860
# 8880
# 8900
# 8920
# 8940
# 8960
# 8980
# 9000
# 9020
# 9040
# 9060
# 9080
# 9100
# 9120
# 9140
# 9160
# 9180
# 9200
# 9220
# 9240
# 9260
# 9280
# 9300
# 9320
# 9340
# 9360
# 9380
# 9400
# 9420
# 9440
# 9460
# 9480
# 9500
# 9520
# 9540
# 9560
# 9580
# 9600
# 9620
# 9640
# 9660
# 9680
# 9700
# 9720
# 9740
# 9760
# 9780
# 9800
# 9820
# 9840
# 9860
# 9880
# 9900
# 9920
# 9940
# 9960
# 9980
# 10000
# 10020
# 10040
# 10060
# 10080
# 10100
# 10120
# 10140
# 10160
# 10180
# 10200
# 10220
# 10240
# 10260
# 10280
# 10300
# 10320
# 10340
# 10360
# 10380
# 10400
# 10420
# 10440
# 10460
# 10480
# 10500
# 10520
# 10540
# 10560
# 10580
# 10600
# 10620
# 10640
# 10660
# 10680
# 10700
# 10720
# 10740
# 10760
# 10780
# 10800
# 10820
# 10840
# 10860
# 10880
# 10900
# 10920
# 10940
# 10960
# 10980
# 11000
# 11020
# 11040
# 11060
# 11080
# 11100
# 11120
# 11140
# 11160
# 11180
# 11200
# 11220
# 11240
# 11260
# 11280
# 11300
# 11320
# 11340
# 11360
# 11380
# 11400
# 11420
# 11440
# 11460
# 11480
# 11500
# 11520
# 11540
# 11560
# 11580
# 11600
# 11620
# 11640
# 11660
# 11680
# 11700
# 11720
# 11740
# 11760
# 11780
# TypeError
# 11800
# 11820
# 11840
# 11860
# 11880
# 11900
# 11920
# 11940
# 11960
# 11980
# 12000
# 12020
# 12040
# 12060
# 12080
# 12100
# 12120
# 12140
# 12160
# 12180
# 12200
# 12220
# 12240
# 12260
# 12280
# 12300
# 12320
# 12340
# 12360
# 12380
# 12400
# 12420
# 12440
# 12460
# 12480
# 12500
# 12520
# 12540
# 12560
# 12580
# 12600
# 12620
# 12640
# 12660
# 12680
# 12700
# 12720
# 12740
# 12760
# 12780
# 12800
# 12820
# 12840
# 12860
# 12880
# 12900
# 12920
# 12940
# 12960
# 12980
# 13000
# 13020
# 13040
# 13060
# 13080
# 13100
# 13120
# 13140
# 13160
# 13180
# 13200
# 13220
# 13240
# 13260
# 13280
# 13300
# 13320
# 13340
# 13360
# 13380
# 13400
# 13420
# 13440
# 13460
# 13480
# 13500
# 13520
# 13540
# 13560
# 13580
# 13600
# 13620
# 13640
# 13660
# 13680
# 13700
# 13720
# 13740
# 13760
# 13780
# 13800
# 13820
# 13840
# 13860
# 13880
# 13900
# 13920
# 13940
# 13960
# 13980
# 14000
# 14020
# 14040
# 14060
#                     phrase restaurantId  review_id  \
# 0             chinese food    chinese_0          0
# 1            food cravings    chinese_0          0
# 2               strip mall    chinese_0          0
# 3       colorado boulevard    chinese_0          0
# 4               eagle rock    chinese_0          0
# 5                food move    chinese_0          0
# 6              pao chicken    chinese_0          0
# 7            veggie medley    chinese_0          0
# 8               white rice    chinese_0          0
# 9             chinese food    chinese_0          1
# 10             food person    chinese_0          1
# 11              veggie pan    chinese_0          1
# 12                kung pao    chinese_0          1
# 13             pao chicken    chinese_0          1
# 14         staff attentive    chinese_0          1
# 15        customer service    chinese_0          3
# 16        inform customers    chinese_0          3
# 17          immature weird    chinese_0          3
# 18               weird way    chinese_0          3
# 19             hot sauce..    chinese_0          3
# 20            on.. ringing    chinese_0          3
# 21        customer service    chinese_0          3
# 22      demographic.. read    chinese_0          3
# 23        customer service    chinese_0          3
# 24      saturday afternoon    chinese_0          4
# 25            mushu shrimp    chinese_0          4
# 26              pau shrimp    chinese_0          4
# 27            tea everyone    chinese_0          4
# 28          leftovers home    chinese_0          4
# 29             brown sauce    chinese_0          5
# ...                    ...          ...        ...
# 37515           spicy food   chinese_50      14063
# 37516     non-spicy diners   chinese_50      14063
# 37517         string beans   chinese_50      14063
# 37518            spicy bbq   chinese_50      14064
# 37519             bbq fish   chinese_50      14064
# 37520      quality service   chinese_50      14064
# 37521       szechuan place   chinese_50      14065
# 37522        appetizer bar   chinese_50      14066
# 37523            bar items   chinese_50      14066
# 37524     items complement   chinese_50      14066
# 37525     appetizer plates   chinese_50      14066
# 37526           spicy food   chinese_50      14067
# 37527           spicy city   chinese_50      14067
# 37528  szechuan restaurant   chinese_50      14068
# 37529          san gabriel   chinese_50      14068
# 37530       gabriel square   chinese_50      14068
# 37531            aka focus   chinese_50      14068
# 37532          focus plaza   chinese_50      14068
# 37533            san diego   chinese_50      14069
# 37534           spicy fish   chinese_50      14069
# 37535          super spicy   chinese_50      14069
# 37536          super tasty   chinese_50      14069
# 37537          san gabriel   chinese_50      14070
# 37538        gabriel plaza   chinese_50      14070
# 37539          spicy level   chinese_50      14070
# 37540           spicy food   chinese_50      14070
# 37541           spicy food   chinese_50      14070
# 37542          san gabriel   chinese_50      14070
# 37543         gabriel area   chinese_50      14070
# 37544         yummy dishes   chinese_50      14070
#
#                                                 sentence  sentence_id
# 0      For all my Chinese food cravings, I come here,...            0
# 1      For all my Chinese food cravings, I come here,...            0
# 2      For all my Chinese food cravings, I come here,...            0
# 3      For all my Chinese food cravings, I come here,...            0
# 4      For all my Chinese food cravings, I come here,...            0
# 5      In general, the flavors of the food move me as...            1
# 6      My favorites are: Kung Pao Chicken, Sechzuan p...            2
# 7      My favorites are: Kung Pao Chicken, Sechzuan p...            2
# 8      My favorites are: Kung Pao Chicken, Sechzuan p...            2
# 9      I've never been a huge Chinese food person but...            0
# 10     I've never been a huge Chinese food person but...            0
# 11     We had the veggie pan fried dumplings, fish wi...            1
# 12     We had the veggie pan fried dumplings, fish wi...            1
# 13     We had the veggie pan fried dumplings, fish wi...            1
# 14     The restaurant is very clean and the staff att...            2
# 15     He argued and yelled at me over the phone abou...            1
# 16     He argued and yelled at me over the phone abou...            1
# 17            Like in a really crazy immature weird way.            2
# 18            Like in a really crazy immature weird way.            2
# 19     (I was charged extra for altering a dish $2 mo...            5
# 20     (I was charged extra for altering a dish $2 mo...            5
# 21     It's maddening when a business ignores custome...            7
# 22     Understand your demographic.. read a book abou...           12
# 23     Understand your demographic.. read a book abou...           12
# 24     Stopped on Saturday afternoon for lunch with a...            0
# 25     We had paper wrapped chicken, Mushu shrimp, Ku...            1
# 26     We had paper wrapped chicken, Mushu shrimp, Ku...            1
# 27     We had paper wrapped chicken, Mushu shrimp, Ku...            1
# 28     I took the leftovers home, and they were even ...            2
# 29     Our server was really friendly and we ordered ...            1
# ...                                                  ...          ...
# 37515  This is my new go-to place for real good spicy...            0
# 37516  For non-spicy diners, try their string beans, ...            4
# 37517  For non-spicy diners, try their string beans, ...            4
# 37518                 The spicy BBQ fish is a must-have.            1
# 37519                 The spicy BBQ fish is a must-have.            1
# 37520  You won't be pissed as long as you don't expec...            3
# 37521            This is my new favorite Szechuan place.            0
# 37522  The best thing about SC is the way the appetiz...            0
# 37523  The best thing about SC is the way the appetiz...            0
# 37524  The best thing about SC is the way the appetiz...            0
# 37525  We order two appetizer plates, each, piled hig...            1
# 37526  I'm not a huge fan of spicy food but having so...            0
# 37527  I went to spicy city in Irvine once and the fo...            1
# 37528  Ambiance: New decor and clean inside, this pla...            0
# 37529  Parking was difficulty to find in the San Gabr...            1
# 37530  Parking was difficulty to find in the San Gabr...            1
# 37531  Parking was difficulty to find in the San Gabr...            1
# 37532  Parking was difficulty to find in the San Gabr...            1
# 37533  Used to eat at the one in San Diego a lot, and...            0
# 37534  We got the Husband and Wife, twice cooked pork...            1
# 37535  Super spicy and super tasty, so i'm very glad ...            3
# 37536  Super spicy and super tasty, so i'm very glad ...            3
# 37537  This newly opened restaurant is located on the...            0
# 37538  This newly opened restaurant is located on the...            0
# 37539  Some food can gets really spicy but you can ch...            3
# 37540  Some food can gets really spicy but you can ch...            3
# 37541  I love spicy food and been to many different o...            7
# 37542  I love spicy food and been to many different o...            7
# 37543  I love spicy food and been to many different o...            7
# 37544  I can't wait to come back again to try all the...            8
#
# [37545 rows x 5 columns]

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Wed Nov  8 14:39:07 2017

@author: enyaning
"""


import pandas as pd
import json

csv_path = 'test.csv'
data = pd.read_csv(csv_path)

reduce1 = {}
print('reducing 1')

for index, row in data.iterrows():
    key = str(row['restaurantId']) + "|" + row['phrase'] + "|" + str(row['review_id']) # + "|" + str(row['sentence_id'])
    if key not in reduce1:
        reduce1[key] = []
    reduce1[key].append(row['sentence'])
    
reduce2 = {}
print('reducing 2')

for k, v in reduce1.items():
    parts = k.split("|")
    key = parts[0] + "|" + parts[1] # restaurantId | phrase
    if key not in reduce2:
        reduce2[key] = []
    reduce2[key].append({'review_id': parts[2], 'sentences': v})

reduce3 = {}
print('reducing 3')

for k, v in reduce2.items():
    parts = k.split("|")
    key = parts[0] # restaurantId
    if key not in reduce3:
        reduce3[key] = []
    reduce3[key].append({'phrase': parts[1], 'reviews': v})
        
def sort_top_100(arr):
    return sorted(arr, key = lambda k: len(k['reviews']), reverse=True)[:100]

print('finally')

res = []
for k, v in reduce3.items():
    res.append({'restaurantId': k, 'top-none-phrases': sort_top_100(v)})
    
with open('json.json', 'w') as f:
    json.dump(res, f, indent=4, sort_keys=True)

res
# Out:
# reducing 1
# reducing 2
# reducing 3
# finally
# [{'restaurantId': 'chinese_27',
#   'top-none-phrases': [{'phrase': 'happy hour',
#     'reviews': [{'review_id': '7418',
#       'sentences': ['Great happy hour food and ambiance nice as well.']},
#      {'review_id': '7600', 'sentences': ['Great happy hour and yummy food.']},
#      {'review_id': '7652',
#       'sentences': ['the food is just a-ok. im sure happy hour is better.']},
#      {'review_id': '7616',
#       'sentences': ['We just love their happy hour prices and food selections.']},
#      {'review_id': '7455', 'sentences': ['Great happy hour!']},
#      {'review_id': '7631',
#       'sentences': ['Our bartender Lisa was very attentive and informed us of all the happy hour specials through out the week.']},
#      {'review_id': '7470',
#       'sentences': ['Make sure to hit up the Happy Hour...']},
#      {'review_id': '7503',
#       'sentences': ['This is our go to favorite Asian fusion restaurant, their Happy Hour is so delightful!']},
#      {'review_id': '7544',
#       'sentences': ['Great happy hour (zen hour) specials, nice atmosphere, tremendous varied menu, and reasonably priced.']},
#      {'review_id': '7523',
#       'sentences': ['We came for the happy hour menu 12-6pm with $9 entrees, $4 beers and wine.']},
#      {'review_id': '7601',
#       'sentences': ['I have enjoyed their happy hour value for over 10 years.']},
#      {'review_id': '7475', 'sentences': ['Great zen time for happy hour.']},
#      {'review_id': '7407',
#       'sentences': ['My go- to place when we have an art group early dinner as they have a long Happy Hour that is lots of fun especially if the group orders dishes to share.']},
#      {'review_id': '7651',
#       'sentences': ["Can't complain about the happy hour also."]},
#      {'review_id': '7461',
#       'sentences': ['This place has great Zen hour (happy hour) on drinks and food.']},
#      {'review_id': '7464',
#       'sentences': ['Geez its happy hour and there are six open tables then we hear there are not enough servers!']},
#      {'review_id': '7427',
#       'sentences': ["Best happy hour ever but shhhhhhhh, don't tell anyone cuz we like to sit at the bar... thank you for such a gem!"]},
#      {'review_id': '7411',
#       'sentences': ["Our favorite bartender is Paolo and the happy hour is the best in town, you'll catch me and my hubby at the bar Thursday night ."]},
#      {'review_id': '7483',
#       'sentences': ['We got in just in time for their happy hour which was amazing!!',
#        'I was glad to find they now allowed you to order from the Happy Hour menu inside and not just on the patio anymore.']},
#      {'review_id': '7610',
#       'sentences': ['Solid chinese food..love the seasme chicken and pot stickers...i highly recommend their happy hour...']},
#      {'review_id': '7634', 'sentences': ['And a super awesome happy hour ;)']},
#      {'review_id': '7527',
#       'sentences': ['We arrived towards the end of happy hour (Sunday) and decided to try a few appetizers before ordering our entrees.']},
#      {'review_id': '7445',
#       'sentences': ['I also had the happy hour Chardonnay and it was Oak-y and yummy!']},
#      {'review_id': '7393',
#       'sentences': ['Fabulous happy hour!',
#        'Great service, a nice selection of happy hour drink specials, and fantastic food.']},
#      {'review_id': '7375',
#       'sentences': ["W's China Bisto is a great gathering place for , amazing food, nice happy hour offerings, and above all, exceptional service."]},
#      {'review_id': '7673',
#       'sentences': ["I'd definitely recommend coming during the happy hour since some of the best dishes are on there for 2-3$ less each."]},
#      {'review_id': '7548', 'sentences': ['Great happy hour!!']},
#      {'review_id': '7568', 'sentences': ['The happy hour is awesome!']},
#      {'review_id': '7591', 'sentences': ['Great happy hour:)']},
#      {'review_id': '7668',
#       'sentences': ['Great happy hour and even better service!',
#        "Both times we've been to W's Rick was bartending and we sat at the rail for happy hour(which is 7 days a week).",
#        'Their happy hour wine was very nice and my fiance was happy to see they had blue moon on happy hour as well.',
#        'Their happy hour wine was very nice and my fiance was happy to see they had blue moon on happy hour as well.']},
#      {'review_id': '7441',
#       'sentences': ['I have been here for lunch and happy hour and there are great deals for both!']},
#      {'review_id': '7629',
#       'sentences': ['My friends and I come here for happy hour all the time!']},
#      {'review_id': '7571',
#       'sentences': ['And believe it or not they even have a daily happy hour with discounted items...']},
#      {'review_id': '7563',
#       'sentences': ['Excellent happy hour menu, friendly service, very impressed, the foods has great flavors, very packed but only 15min wait for table, the manager was really nice and offer to get us our drinks started while we wait for our table, will definitely come back']},
#      {'review_id': '7469',
#       'sentences': ['Definitely have to try out the Zen Time for happy hour!']},
#      {'review_id': '7617',
#       'sentences': ['They also have a wonderful happy hour!']},
#      {'review_id': '7374',
#       'sentences': ["First time in stopped for carryout and was welcomed like I'm family they were all so charming and thoughtful and when they talked about their happy hour or menu it was more like an invite to hang out."]},
#      {'review_id': '7386',
#       'sentences': ["Looks like they have a good happy hour but didn't get to try it yet."]},
#      {'review_id': '7385',
#       'sentences': ['Stopped in for Sen Hour (happy Hour prices) - no reservation, but we were seated immediately.']},
#      {'review_id': '7603',
#       'sentences': ["The best part of W's is the Zen Hour (happy Hour)."]},
#      {'review_id': '7493', 'sentences': ['Love the Happy Hour!']},
#      {'review_id': '7553',
#       'sentences': ['They also have a good happy hour but it gets really crowded on Friday and the weekends.']},
#      {'review_id': '7594',
#       'sentences': ["They have a great happy hour, and the portions can't be beat anywhere."]},
#      {'review_id': '7409', 'sentences': ['COME FOR HAPPY HOUR!']},
#      {'review_id': '7654',
#       'sentences': ['The happy hour is perfect for a light dinner with apps and drinks.',
#        'Get there before 6 to take advantage of the only happy hour in the state of California.']},
#      {'review_id': '7595',
#       'sentences': ['The happy hour specials are awesome!']},
#      {'review_id': '7509', 'sentences': ['Good happy hour prices!']},
#      {'review_id': '7397',
#       'sentences': ['We ordered a bunch of plates off of the Happy hour menu and everyone of them was delicious.']}]},
#    {'phrase': 'chinese food',
#     'reviews': [{'review_id': '7523',
#       'sentences': ['Easily my favorite Chinese food.']},
#      {'review_id': '7623',
#       'sentences': ['Hands down the best Chinese food I have ever had.']},
#      {'review_id': '7647',
#       'sentences': ["The food here is not authentic Chinese food, I don't even think authentic Chinese still exist in Los Angeles, but it was well made not too salty, greasy, or sweet."]},
#      {'review_id': '7538',
#       'sentences': ['This is by far the best Chinese food that I have ever had!']},
#      {'review_id': '7617',
#       'sentences': ['Ive been going here for about 5 years, and when I have a craving for GREAT Chinese food this is where I go.']},
#      {'review_id': '7569',
#       'sentences': ["This wasn't anything like Chinese food you would normally have everywhere."]},
#      {'review_id': '7531',
#       'sentences': ['This place is okay if u like American style Chinese Food.']},
#      {'review_id': '7529',
#       'sentences': ['Consistently, this is the best Chinese food restaurant in this area.']},
#      {'review_id': '7417',
#       'sentences': ['This is probably the best Chinese food in South Bay.']},
#      {'review_id': '7434',
#       'sentences': ['We have been here a few times now and the food is probably the best Chinese food in the area.']},
#      {'review_id': '7519',
#       'sentences': ["Definitely is the best Chinese food I've ever had."]},
#      {'review_id': '7584',
#       'sentences': ['So this place is almost my favorite Chinese food in the South Bay.']},
#      {'review_id': '7441',
#       'sentences': ['This is without a doubt the best Chinese food in the South Bay.',
#        'It is a little bit pricier than the Chinese food places in the area but the food is not your typical take out greasy Chinese food.']},
#      {'review_id': '7571',
#       'sentences': ['This is not the AmericanIZED greasy Chinese food we are used to but a much lighter, home cooked version....']},
#      {'review_id': '7579',
#       'sentences': ['.No Chinese food can compare in my eyes !']},
#      {'review_id': '7400',
#       'sentences': ['This is hands down the best Chinese food in the South Bay!!!']},
#      {'review_id': '7547',
#       'sentences': ['Very good Chinese food.',
#        'Highly recommend this place for someone crazing Chinese food!']},
#      {'review_id': '7608', 'sentences': ['Great Chinese food.']},
#      {'review_id': '7670',
#       'sentences': ["I've been looking for a good Chinese food place ever since I moved to Redondo Beach."]}]},
#    {'phrase': 'south bay',
#     'reviews': [{'review_id': '7584',
#       'sentences': ['So this place is almost my favorite Chinese food in the South Bay.']},
#      {'review_id': '7400',
#       'sentences': ['This is hands down the best Chinese food in the South Bay!!!']},
#      {'review_id': '7640',
#       'sentences': ['The variety and quality of the food here is some of the best in the South Bay, they also have a great lunch menu with very reasonable prices.']},
#      {'review_id': '7540',
#       'sentences': ['Definitely would recommend this business to anybody in the south bay']},
#      {'review_id': '7414',
#       'sentences': ['Best chinese food in the South Bay by far!']},
#      {'review_id': '7621',
#       'sentences': ['My husband and I are big Chinese food fans and recently moved down to the South Bay and this was our first try.']},
#      {'review_id': '7455', 'sentences': ['Best value in South Bay !']},
#      {'review_id': '7427',
#       'sentences': ['The service is incredible Rick is the best bartender in the South Bay!']},
#      {'review_id': '7481',
#       'sentences': ['Over-priced, but that seems to be accepted in South Bay beach cities.',
#        'South Bay has much better options available at better prices and quality.']},
#      {'review_id': '7651', 'sentences': ['Best Chinese in the South Bay!']},
#      {'review_id': '7379',
#       'sentences': ['Easily the best Chinese in the South Bay.']},
#      {'review_id': '7591',
#       'sentences': ["Rick was an amazing waiter and we finally found Chinese food in the South Bay that is made fresh and doesn't taste like it was made 2 weeks ago and reheated a hundred times!!!"]},
#      {'review_id': '7538',
#       'sentences': ['I will surely miss eating here as I am moving out of the South Bay....']},
#      {'review_id': '7417',
#       'sentences': ['This is probably the best Chinese food in South Bay.',
#        'Then, our server, Nathan, gave the most accommodating service I have had in South Bay!']},
#      {'review_id': '7426',
#       'sentences': ["I've been looking for a good chinese place in the South Bay and we finally found it."]},
#      {'review_id': '7500', 'sentences': ['Best Chinese food in South Bay!']},
#      {'review_id': '7441',
#       'sentences': ['This is without a doubt the best Chinese food in the South Bay.']}]},
#    {'phrase': 'orange chicken',
#     'reviews': [{'review_id': '7590',
#       'sentences': ['I always get the orange chicken.']},
#      {'review_id': '7433',
#       'sentences': ['I had their orange chicken lunch plate with chowmein instead of rice.']},
#      {'review_id': '7646',
#       'sentences': ['Decent pricing, in the mood for some orange chicken, boom, done!']},
#      {'review_id': '7426',
#       'sentences': ["I can't wait to try the orange chicken and beef with broccoli."]},
#      {'review_id': '7519',
#       'sentences': ['I got the orange chicken and it was the best orange chicken I have ever had.']},
#      {'review_id': '7523',
#       'sentences': ['The orange chicken was lightly battered and wonderfully flavored.']},
#      {'review_id': '7605',
#       'sentences': ['The orange chicken, chicken lettuce cups, garlic noodles, poke, calamari ahh..all are great!']},
#      {'review_id': '7653',
#       'sentences': ['The orange chicken was amazing however in the last year them must have changed something and I really do not care for the orange chicken any longer..... A year ago I would have given it 5 stars....',
#        'The orange chicken was amazing however in the last year them must have changed something and I really do not care for the orange chicken any longer..... A year ago I would have given it 5 stars....']},
#      {'review_id': '7384',
#       'sentences': ["The sesame chicken is similar to the well known Panda Express's orange chicken but way better."]},
#      {'review_id': '7636',
#       'sentences': ['I really love this place...Though I tend to order the same things every time I come, (the famous Orange Chicken, Wan Ton Soup, (my favorite in all of LA) and the mixed Veggie Melange), my visit last night stood out from the rest due to the outstanding service we received from our waiter Ryan.']},
#      {'review_id': '7602',
#       'sentences': ['I keep coming back for the orange chicken and crispy sesame chicken.']},
#      {'review_id': '7385',
#       'sentences': ['The Orange chicken is the top of our list.']},
#      {'review_id': '7453',
#       'sentences': ['I usually opt for the ws Chicken, or the orange chicken.']},
#      {'review_id': '7631',
#       'sentences': ['I was first served and the garlic noodles, so when I got our noodles and orange chicken altogether it was just fine, and tasted delicious.']},
#      {'review_id': '7467',
#       'sentences': ['The first bite of the orange chicken and egg rolls was absolutely amazing, you can be sure fresh ingredients are being used.']},
#      {'review_id': '7558',
#       'sentences': ['We always enjoy their Chicken Pad Thai, Garlic Noodles and the Orange Chicken.']}]},
#    {'phrase': 'cream cheese',
#     'reviews': [{'review_id': '7400',
#       'sentences': ['Free cream cheese wontons with Yelp check-in as well!']},
#      {'review_id': '7539',
#       'sentences': ['He told us right away about a yelp check in for their delicious cream cheese wontons.']},
#      {'review_id': '7475',
#       'sentences': ['The cream cheese wonton was good too']},
#      {'review_id': '7519',
#       'sentences': ['We used the coupon thing for the cream cheese wontons, and they were also amazing.']},
#      {'review_id': '7403',
#       'sentences': ["There's also a coupon for a free fried cream cheese wonton worth $5.75 if you check in at Yelp."]},
#      {'review_id': '7514',
#       'sentences': ['We also had the cream cheese wontons too and those were good.']},
#      {'review_id': '7389',
#       'sentences': ['We had cream cheese wontons, calamari, garlic noodles, green beans, bulgogi steak, and kungpao chicken.']},
#      {'review_id': '7438',
#       'sentences': ['Almost forgot, had crabmeat, shrimp, nut, cream cheese cigars appetizers ..']},
#      {'review_id': '7607',
#       'sentences': ['Food was delicious and the free cream cheese wontons for checking in was an added bonus!']},
#      {'review_id': '7505',
#       'sentences': ['We sat down and of course I checked in on Yelp and got a free cream cheese wonton appetizer.']},
#      {'review_id': '7527',
#       'sentences': ['Oh - we redeemed the free cream cheese won-tons by checking-in via yelp.']},
#      {'review_id': '7500',
#       'sentences': ['We ordered the cream cheese wontons, ahi poke, beef chow mein crispy, and sesame chicken.']}]},
#    {'phrase': 'chinese restaurant',
#     'reviews': [{'review_id': '7467',
#       'sentences': ["By far the best Chinese restaurant I've EVER had!"]},
#      {'review_id': '7384',
#       'sentences': ['This is a fantastic Chinese restaurant.']},
#      {'review_id': '7386',
#       'sentences': ['Prices are a little higher than your typical Chinese restaurant, but the atmosphere in the restaurant is a little more upscale and portions are big.']},
#      {'review_id': '7549',
#       'sentences': ['I think I found my favorite Chinese Restaurant, Food is amazing, ambience us really nice prices are decent,']},
#      {'review_id': '7631',
#       'sentences': ['So glad I checked yelp before choosing just any old Chinese restaurant.']},
#      {'review_id': '7401',
#       'sentences': ["W's is the best Chinese restaurant we've found since moving to So Cal."]},
#      {'review_id': '7487',
#       'sentences': ['A decent Chinese Restaurant that I can dine in with a nice decor.']},
#      {'review_id': '7383',
#       'sentences': ['Tried this restaurant out last night after searching for a good Chinese restaurant on Yelp.']},
#      {'review_id': '7617',
#       'sentences': ['Its not your ordinary Chinese Restaurant !']},
#      {'review_id': '7663',
#       'sentences': ['Very nice American Chinese restaurant.']},
#      {'review_id': '7500',
#       'sentences': ["It's definitely not your typical Chinese restaurant."]}]},
#    {'phrase': 'china bistro',
#     'reviews': [{'review_id': '7429',
#       'sentences': ["We always have a delightful dining experience at W's China Bistro."]},
#      {'review_id': '7603',
#       'sentences': ["W's China Bistro is out of this world!"]},
#      {'review_id': '7670', 'sentences': ["W's China Bistro is very good."]},
#      {'review_id': '7461',
#       'sentences': ["The both time visiting W's China Bistro we have we choose the patio seating and enjoyed the nice breeze."]},
#      {'review_id': '7491',
#       'sentences': ["Here is what I thought of W's China bistro:"]},
#      {'review_id': '7632',
#       'sentences': ["Had dinner at W's China Bistro last Wednesday with a Dial-A-Ride group of about 30 people."]},
#      {'review_id': '7559',
#       'sentences': ["My friend and I were visiting California and stumbled upon W's china bistro."]},
#      {'review_id': '7545', 'sentences': ["W's China Bistro"]},
#      {'review_id': '7667',
#       'sentences': ['The W\'s China Bistro is located in the "avenue\'s" area, I think next to AVENUE G of Redondo Beach, walking distance from the beach front strand area within 2 blocks or so, and is the perfect location.']},
#      {'review_id': '7571',
#       'sentences': ['I try to lay off fried food (for obvious reasons) however, I have become addicted to the "cigars" and Eggrolls... Don;t event get me started on the GARLIC NOODLES... W O W... China Bistro even posts the recipes for various menu options.. how cool is that?']}]},
#    {'phrase': 'cheese wontons',
#     'reviews': [{'review_id': '7607',
#       'sentences': ['Food was delicious and the free cream cheese wontons for checking in was an added bonus!']},
#      {'review_id': '7539',
#       'sentences': ['He told us right away about a yelp check in for their delicious cream cheese wontons.']},
#      {'review_id': '7389',
#       'sentences': ['We had cream cheese wontons, calamari, garlic noodles, green beans, bulgogi steak, and kungpao chicken.']},
#      {'review_id': '7500',
#       'sentences': ['We ordered the cream cheese wontons, ahi poke, beef chow mein crispy, and sesame chicken.']},
#      {'review_id': '7400',
#       'sentences': ['Free cream cheese wontons with Yelp check-in as well!']},
#      {'review_id': '7519',
#       'sentences': ['We used the coupon thing for the cream cheese wontons, and they were also amazing.']},
#      {'review_id': '7514',
#       'sentences': ['We also had the cream cheese wontons too and those were good.']}]},
#    {'phrase': 'zen hour',
#     'reviews': [{'review_id': '7603',
#       'sentences': ["The best part of W's is the Zen Hour (happy Hour)."]},
#      {'review_id': '7608',
#       'sentences': ['By the way Zen hour Monday through Thursday 4-7 Friday-Saturday 4-6 sunday 12-6.']},
#      {'review_id': '7544',
#       'sentences': ['Great happy hour (zen hour) specials, nice atmosphere, tremendous varied menu, and reasonably priced.']},
#      {'review_id': '7666',
#       'sentences': ["If you go to their website you'll see a link for their Zen Hour Menu, it has their days/hours posted."]},
#      {'review_id': '7578',
#       'sentences': ['Servers were attentive and helpful and made sure we stayed in top of the Zen hour specials, which by the way are really terrific.']},
#      {'review_id': '7461',
#       'sentences': ['This place has great Zen hour (happy hour) on drinks and food.']}]},
#    {'phrase': 'pf changs',
#     'reviews': [{'review_id': '7673',
#       'sentences': ["I keep seeing reviews with comparisons to a nicer PF Changs and that isn't too far off."]},
#      {'review_id': '7603',
#       'sentences': ["It's like a knock off version of PF Changs, but way better!"]},
#      {'review_id': '7586',
#       'sentences': ['Will never eat at PF Changs again!']},
#      {'review_id': '7472',
#       'sentences': ["On our first visit there, the waiter proudly stated that W's is 2 to 3x better than PF Changs.",
#        "In my opinion W's is 10x better than PF Changs."]},
#      {'review_id': '7654',
#       'sentences': ['The food is regular Chinese food without flair of PF Changs.']},
#      {'review_id': '7664',
#       'sentences': ['very good, way better than pf changs']}]},
#    {'phrase': 'hour menu',
#     'reviews': [{'review_id': '7666',
#       'sentences': ["If you go to their website you'll see a link for their Zen Hour Menu, it has their days/hours posted."]},
#      {'review_id': '7523',
#       'sentences': ['We came for the happy hour menu 12-6pm with $9 entrees, $4 beers and wine.']},
#      {'review_id': '7397',
#       'sentences': ['We ordered a bunch of plates off of the Happy hour menu and everyone of them was delicious.']},
#      {'review_id': '7656',
#       'sentences': ["However, it's good food and they have a happy hour menu."]},
#      {'review_id': '7563',
#       'sentences': ['Excellent happy hour menu, friendly service, very impressed, the foods has great flavors, very packed but only 15min wait for table, the manager was really nice and offer to get us our drinks started while we wait for our table, will definitely come back']},
#      {'review_id': '7483',
#       'sentences': ['I was glad to find they now allowed you to order from the Happy Hour menu inside and not just on the patio anymore.']}]},
#    {'phrase': 'spring rolls',
#     'reviews': [{'review_id': '7553',
#       'sentences': ['There are several dishes that they do very well including the garlic noodles, cashew chicken, fried rice and spring rolls.']},
#      {'review_id': '7412',
#       'sentences': ['I recommend the fiery fish, garlic noodles and spring rolls!']},
#      {'review_id': '7612',
#       'sentences': ['Sad that they stopped serving their great Spring Rolls with lunch and dinner.']},
#      {'review_id': '7489',
#       'sentences': ["If you liked spring rolls, you will LOVE spring rolls after eating W's!!!!"]},
#      {'review_id': '7417',
#       'sentences': ['My husband and I ordered lettuce wraps, spring rolls, orange chicken, and the honey walnut shrimp and we were more than impressed!']},
#      {'review_id': '7603',
#       'sentences': ['Best spring rolls I have ever had, the Shrimp cigars are to die for.']}]},
#    {'phrase': 'walnut shrimp',
#     'reviews': [{'review_id': '7416',
#       'sentences': ['Walnut Shrimp and Mongolian beef was really tasty.']},
#      {'review_id': '7539',
#       'sentences': ['The crispy honey walnut shrimp is also amazing.']},
#      {'review_id': '7512',
#       'sentences': ["Don't get the honey walnut shrimp because they only give you a measly six pieces."]},
#      {'review_id': '7548',
#       'sentences': ['The fiery fish strips were delish and the honey walnut shrimp was tasty.']},
#      {'review_id': '7417',
#       'sentences': ['My husband and I ordered lettuce wraps, spring rolls, orange chicken, and the honey walnut shrimp and we were more than impressed!']}]},
#    {'phrase': 'chinese place',
#     'reviews': [{'review_id': '7513',
#       'sentences': ["This is our favorite Chinese place and that's why I won't go down to 3 stars but I will refuse to sit in Sam's section."]},
#      {'review_id': '7436',
#       'sentences': ['My favorite upscale chinese place.']},
#      {'review_id': '7426',
#       'sentences': ["I've been looking for a good chinese place in the South Bay and we finally found it."]},
#      {'review_id': '7525',
#       'sentences': ['Great service great food my new favorite Chinese place.']},
#      {'review_id': '7564',
#       'sentences': ['High end Chinese place with delicious food.']}]},
#    {'phrase': 'ahi poke',
#     'reviews': [{'review_id': '7530',
#       'sentences': ["I just had my most favorite won't ton soup and ahi poke, I just gotta say their food is fantastic and the deco is set right a great bar and can still get the game!"]},
#      {'review_id': '7480',
#       'sentences': ['The appetizer, ahi poke, was light, refreshing, and delicious!']},
#      {'review_id': '7622',
#       'sentences': ['We started with the ahi poke and went on to have the sea bass and various other dishes which were recommended by our waiter (Nick).']},
#      {'review_id': '7580',
#       'sentences': ["The ahi poke, garlic noodles, and w's chicken are really yummy."]},
#      {'review_id': '7629',
#       'sentences': ['Be sure to try the ahi poke and the garlic noodles, my favorites off the hh menu!']}]},
#    {'phrase': 'egg rolls',
#     'reviews': [{'review_id': '7400',
#       'sentences': ["Our standard items that we can't do without are: the Mongolian beef, chicken with black bean sauce, the crunchy egg rolls, fiery fish, General W's chicken, and Szechuan eggplant."]},
#      {'review_id': '7467',
#       'sentences': ['The first bite of the orange chicken and egg rolls was absolutely amazing, you can be sure fresh ingredients are being used.']},
#      {'review_id': '7397',
#       'sentences': ["We got chicken Fried rice (it's a generous plate), crab cigars (like egg rolls), broccoli beef, bbq spare ribs, spicy wontons, calamari and a couple more."]},
#      {'review_id': '7439',
#       'sentences': ['Mongolian beef, General Ws chicken, garlic noodles and the Krazy egg rolls were so good.']},
#      {'review_id': '7554',
#       'sentences': ['The crazy egg rolls were very good, not greasy at all.']}]},
#    {'phrase': 'fiery fish',
#     'reviews': [{'review_id': '7400',
#       'sentences': ["Our standard items that we can't do without are: the Mongolian beef, chicken with black bean sauce, the crunchy egg rolls, fiery fish, General W's chicken, and Szechuan eggplant."]},
#      {'review_id': '7412',
#       'sentences': ['I recommend the fiery fish, garlic noodles and spring rolls!']},
#      {'review_id': '7548',
#       'sentences': ['The fiery fish strips were delish and the honey walnut shrimp was tasty.']},
#      {'review_id': '7616',
#       'sentences': ['Love the chicken lettuce wraps and the fiery fish.']}]},
#    {'phrase': 'dining experience',
#     'reviews': [{'review_id': '7429',
#       'sentences': ["We always have a delightful dining experience at W's China Bistro.",
#        'Polo is an excellent host and he always ensures we enjoy a superior dining experience.']},
#      {'review_id': '7578',
#       'sentences': ['Despite is being a very busy Friday night, my dining experience was quite fantastic.']},
#      {'review_id': '7517',
#       'sentences': ['Bad dining experience, do not recommend...']},
#      {'review_id': '7430',
#       'sentences': ["Initially I thought he was the owner because of the way he strives to make sure everyone's dining experience is nothing short of excellent."]}]},
#    {'phrase': 'date night',
#     'reviews': [{'review_id': '7505',
#       'sentences': ['My wife brought me here on date night.',
#        'Great date night.']},
#      {'review_id': '7547', 'sentences': ['Good place for a date night.']},
#      {'review_id': '7593',
#       'sentences': ['I like to think of this place an impressive date night spot.']},
#      {'review_id': '7620',
#       'sentences': ['Went there a few years ago for a date night and we were blown away!']}]},
#    {'phrase': 'honey walnut',
#     'reviews': [{'review_id': '7539',
#       'sentences': ['The crispy honey walnut shrimp is also amazing.']},
#      {'review_id': '7417',
#       'sentences': ['My husband and I ordered lettuce wraps, spring rolls, orange chicken, and the honey walnut shrimp and we were more than impressed!']},
#      {'review_id': '7512',
#       'sentences': ["Don't get the honey walnut shrimp because they only give you a measly six pieces."]},
#      {'review_id': '7548',
#       'sentences': ['The fiery fish strips were delish and the honey walnut shrimp was tasty.']}]},
#    {'phrase': 'redondo beach',
#     'reviews': [{'review_id': '7418',
#       'sentences': ['Great location on PCH in Redondo Beach.']},
#      {'review_id': '7659',
#       'sentences': ['Pretty good find in the Redondo Beach area.']},
#      {'review_id': '7667',
#       'sentences': ['The W\'s China Bistro is located in the "avenue\'s" area, I think next to AVENUE G of Redondo Beach, walking distance from the beach front strand area within 2 blocks or so, and is the perfect location.']},
#      {'review_id': '7570',
#       'sentences': ["So while on vacation in Redondo beach I got a random craving for Orange chicken Im not a big fan of trying out chicken anywhere unless I'm familiar with it but looking at the pictures on yelp it looked delicious and awesome reviews so I took a chance & stopped there!"]}]},
#    {'phrase': 'spare ribs',
#     'reviews': [{'review_id': '7394',
#       'sentences': ['We had the spare ribs and they were fantastic.']},
#      {'review_id': '7397',
#       'sentences': ["We got chicken Fried rice (it's a generous plate), crab cigars (like egg rolls), broccoli beef, bbq spare ribs, spicy wontons, calamari and a couple more."]},
#      {'review_id': '7527',
#       'sentences': ['We also ordered Kung pao chicken, garlic noodles w/ chicken, and we tried the BBQ spare ribs.']},
#      {'review_id': '7504',
#       'sentences': ['Great hot and sour soup, lettuce cups, ahi poke and spare ribs for appetizers.For our mains, we shared the crispy prawns and hot pot fish, (accompanied for 2 bucks extra by the garlic noodles) and a side of spicy string beans.']}]},
#    {'phrase': 'wonton soup',
#     'reviews': [{'review_id': '7462',
#       'sentences': ["NJ meets Cali....very very good....nj spareribs portions are larger but these in Cali fall off the bone...not to saucy....cooked well....their crispy noodles are very good as well.....we also ordered wonton soup...the sliced ginger in the soup was amazing....very good..I will ask for that in NJ...beef chow fun...#1 noodles are homemade...you can't get that unless you are in Chinatown.....very friendly staff.....wine very good..."]},
#      {'review_id': '7402', 'sentences': ['I love their classic wonton soup.']},
#      {'review_id': '7383',
#       'sentences': ["We had pineapple chicken, garlic noodles, wonton soup, and some sort of beef that I can't remember the name but was so tender it melted in your mouth."]},
#      {'review_id': '7551',
#       'sentences': ['Best Wonton soup I have ever had!']}]},
#    {'phrase': 'kung pao',
#     'reviews': [{'review_id': '7578',
#       'sentences': ['Crab stuffed cigar rolls, Kung pao chicken, spicy beef and spicy noodles...all delicious, but I admit I enjoyed the beef a bit more than my Kung pao chicken.']},
#      {'review_id': '7495',
#       'sentences': ['We had the Kung Pao chicken, Asian ribs, cheese wontons and creme brulee for dessert.']},
#      {'review_id': '7528',
#       'sentences': ['One of the local restaurants that are offer a discount for using the Axxess card, so I figured we would give it a try, ordered the Kung Pao chicken, Chicken fried rice and Northern Mongolian Beef,']},
#      {'review_id': '7423',
#       'sentences': ['The food (Kung Pao Chicken to be specific) was top notch.']}]},
#    {'phrase': 'pao chicken',
#     'reviews': [{'review_id': '7528',
#       'sentences': ['One of the local restaurants that are offer a discount for using the Axxess card, so I figured we would give it a try, ordered the Kung Pao chicken, Chicken fried rice and Northern Mongolian Beef,']},
#      {'review_id': '7495',
#       'sentences': ['We had the Kung Pao chicken, Asian ribs, cheese wontons and creme brulee for dessert.']},
#      {'review_id': '7423',
#       'sentences': ['The food (Kung Pao Chicken to be specific) was top notch.']},
#      {'review_id': '7578',
#       'sentences': ['Crab stuffed cigar rolls, Kung pao chicken, spicy beef and spicy noodles...all delicious, but I admit I enjoyed the beef a bit more than my Kung pao chicken.',
#        'Crab stuffed cigar rolls, Kung pao chicken, spicy beef and spicy noodles...all delicious, but I admit I enjoyed the beef a bit more than my Kung pao chicken.']}]},
#    {'phrase': 'valet parking',
#     'reviews': [{'review_id': '7554',
#       'sentences': ['They also offered free valet parking in back.']},
#      {'review_id': '7505',
#       'sentences': ['They also have free valet Parking.']},
#      {'review_id': '7480',
#       'sentences': ['From the valet parking attendant, to the hosts, to the server, to the food, to the manager, the service and food was outstanding.']},
#      {'review_id': '7403',
#       'sentences': ['Free valet parking in the rear just tip the attendant.']}]},
#    {'phrase': 'lettuce wraps',
#     'reviews': [{'review_id': '7417',
#       'sentences': ['My husband and I ordered lettuce wraps, spring rolls, orange chicken, and the honey walnut shrimp and we were more than impressed!']},
#      {'review_id': '7481',
#       'sentences': ['Honey Walnut shrimp was pretty good with 6 large prawns, and the chicken lettuce wraps were good also.',
#        'Chicken Lettuce wraps are $9 apps.']},
#      {'review_id': '7616',
#       'sentences': ['Love the chicken lettuce wraps and the fiery fish.']}]},
#    {'phrase': 'customer service',
#     'reviews': [{'review_id': '7543',
#       'sentences': ['The customer service is a bit questionable though - we got our order to go and they forgot two parts of our order.']},
#      {'review_id': '7621',
#       'sentences': ['If I could base this review solely on customer service I would give it five stars.',
#        'The customer service was impeccable.']},
#      {'review_id': '7410',
#       'sentences': ['Seems they lack some customer service training']}]},
#    {'phrase': 'cheese wonton',
#     'reviews': [{'review_id': '7403',
#       'sentences': ["There's also a coupon for a free fried cream cheese wonton worth $5.75 if you check in at Yelp."]},
#      {'review_id': '7505',
#       'sentences': ['We sat down and of course I checked in on Yelp and got a free cream cheese wonton appetizer.']},
#      {'review_id': '7475',
#       'sentences': ['The cream cheese wonton was good too']}]},
#    {'phrase': 'panda express',
#     'reviews': [{'review_id': '7590',
#       'sentences': ['Beats the hell out of Panda Express.']},
#      {'review_id': '7378',
#       'sentences': ['The Szechwan or Chuan cuisine was wonderfully non greasy un like the usual Panda Express faire The waiter didn\'t know how to advise me to order- "we have meat - chicken fish beef"']},
#      {'review_id': '7384',
#       'sentences': ["The sesame chicken is similar to the well known Panda Express's orange chicken but way better."]}]},
#    {'phrase': 'creme brle',
#     'reviews': [{'review_id': '7558',
#       'sentences': ['They also have the best Creme brle .']},
#      {'review_id': '7660',
#       'sentences': ["Love w's my family and I had dinner last night the restaurant was extremely busy We had to wait longer than usual for our entrees but def enjoy the food as always the waiter was great , the manager came to our table and apologize for the wait and took care of the appetizer and gave my daughter a delicious creme brle , see you guys soon"]},
#      {'review_id': '7452',
#       'sentences': ['Creme brle here is to die for , will be back soon .']}]},
#    {'phrase': 'wait time',
#     'reviews': [{'review_id': '7611',
#       'sentences': ["I'm not usually one to count the minutes of my wait time, but I was pretty hangry."]},
#      {'review_id': '7434',
#       'sentences': ['The only problem is the wait time for service!']},
#      {'review_id': '7496',
#       'sentences': ["The wait time isn't long at all and the price is neither too cheap nor expensive; the price is just right."]}]},
#    {'phrase': 'spring roll',
#     'reviews': [{'review_id': '7428',
#       'sentences': ['Not sure if it was us, or a regular thing, but they threw in some lovely crispy wonton and a spring roll...my husband states it was the best chicken cashew he has had in LA!']},
#      {'review_id': '7585',
#       'sentences': ['What put this at 5 stars was the banana spring roll with house made banana ice cream OMG the bomb']},
#      {'review_id': '7475',
#       'sentences': ['Their vegetable spring roll is too oily for me.']}]},
#    {'phrase': 'drink order',
#     'reviews': [{'review_id': '7598',
#       'sentences': ["We had to ask the first person we saw (I think it was one of the supervisors) for someone to take our drink order, The beer that I've ordered was flat but it was not a big deal."]},
#      {'review_id': '7559',
#       'sentences': ['No one came to greet us or ask us for our drink order for at least 10 minutes, maybe more like 15.']},
#      {'review_id': '7449',
#       'sentences': ['Waited 10 minutes for someone to take our drink order.']}]},
#    {'phrase': 'ton soup',
#     'reviews': [{'review_id': '7670',
#       'sentences': ['Won Ton soup cup, very flavorful.']},
#      {'review_id': '7636',
#       'sentences': ['I really love this place...Though I tend to order the same things every time I come, (the famous Orange Chicken, Wan Ton Soup, (my favorite in all of LA) and the mixed Veggie Melange), my visit last night stood out from the rest due to the outstanding service we received from our waiter Ryan.']},
#      {'review_id': '7394',
#       'sentences': ["Won Ton soup was super fresh, some of the best I've had."]}]},
#    {'phrase': 'manager polo',
#     'reviews': [{'review_id': '7439',
#       'sentences': ['The manager Polo came by to make sure everything was going great.']},
#      {'review_id': '7613',
#       'sentences': ['the manager Polo made us feel so comfortable.',
#        'the manager Polo even gave us the history of this restaurant.']},
#      {'review_id': '7427',
#       'sentences': ['Their manager Polo is so fun and the best EVER, great service ALWAYS!!!']}]},
#    {'phrase': 'friday night',
#     'reviews': [{'review_id': '7644',
#       'sentences': ["This review would be 5 stars if it wasn't for the service I received at dinner last Friday night."]},
#      {'review_id': '7622',
#       'sentences': ['Me, my mom and grandmother went here Friday night for dinner not knowing what to expect.']},
#      {'review_id': '7578',
#       'sentences': ['Despite is being a very busy Friday night, my dining experience was quite fantastic.']}]},
#    {'phrase': 'spicy shrimp',
#     'reviews': [{'review_id': '7479',
#       'sentences': ["Yummy food I especially love the spicy shrimp I substitute the onions with snow pea's i also love the tuna tartare (poke) and the Hunan beef is also kine grindz one thing I didn't like was there Orange chicken I'm very picky when it comes to that so I wasn't impressed.....I love how they have a full bar in the restaurant so I can order more than Sake and wine....The service is great and they always aim to please"]},
#      {'review_id': '7505',
#       'sentences': ['We ordered there beef broccoli, orange chicken, garlic noodles and spicy shrimp and it was all very good.']},
#      {'review_id': '7480',
#       'sentences': ['The owner immediately appeared, suggested a different dish, and promptly brought us a spicy shrimp and broccoli entree instead.']}]},
#    {'phrase': 'soy sauce',
#     'reviews': [{'review_id': '7517',
#       'sentences': ['We asked for a hot and soy sauce to add some taste to it, but they never arrived.']},
#      {'review_id': '7447',
#       'sentences': ['The rice was drenched in soy sauce.']},
#      {'review_id': '7559',
#       'sentences': ['When a girl brought us our fried rice I asked for some soy sauce.',
#        'She barely acknowledged me and walked away, a minute later she came back and just slammed the soy sauce down on the opposite side of the table from me without even a word.']}]},
#    {'phrase': 'lettuce cups',
#     'reviews': [{'review_id': '7560',
#       'sentences': ['Oh, they have great lettuce cups, shrimp cigars, garlic noodles, and much more.']},
#      {'review_id': '7605',
#       'sentences': ['The orange chicken, chicken lettuce cups, garlic noodles, poke, calamari ahh..all are great!']},
#      {'review_id': '7504',
#       'sentences': ['Great hot and sour soup, lettuce cups, ahi poke and spare ribs for appetizers.For our mains, we shared the crispy prawns and hot pot fish, (accompanied for 2 bucks extra by the garlic noodles) and a side of spicy string beans.']}]},
#    {'phrase': 'hour specials',
#     'reviews': [{'review_id': '7595',
#       'sentences': ['The happy hour specials are awesome!']},
#      {'review_id': '7631',
#       'sentences': ['Our bartender Lisa was very attentive and informed us of all the happy hour specials through out the week.']},
#      {'review_id': '7578',
#       'sentences': ['Servers were attentive and helpful and made sure we stayed in top of the Zen hour specials, which by the way are really terrific.']}]},
#    {'phrase': 'sesame chicken',
#     'reviews': [{'review_id': '7635',
#       'sentences': ['I recommend the Sesame Chicken and the Garlic Noodles.']},
#      {'review_id': '7576',
#       'sentences': ['The sesame chicken was our favorite of the night, but everything else was great.']},
#      {'review_id': '7384',
#       'sentences': ['There are various things to try on this menu, but I would personally suggest the garlic noodles with shrimp and the sesame chicken.',
#        "The sesame chicken is similar to the well known Panda Express's orange chicken but way better."]}]},
#    {'phrase': 'spicy noodles',
#     'reviews': [{'review_id': '7631',
#       'sentences': ['I had ordered spicy noodles and about 5 minutes into eating, a waiter brought a second noodle order which was the spicy noodles.',
#        'I had ordered spicy noodles and about 5 minutes into eating, a waiter brought a second noodle order which was the spicy noodles.',
#        'I had not known the difference between the garlic and spicy noodles.',
#        'Then when the spicy noodles were brought out and the mistake was recognized it was a nice surprise for two noodle dishes.']},
#      {'review_id': '7432',
#       'sentences': ['We also ordered a side of spicy noodles.']},
#      {'review_id': '7578',
#       'sentences': ['Crab stuffed cigar rolls, Kung pao chicken, spicy beef and spicy noodles...all delicious, but I admit I enjoyed the beef a bit more than my Kung pao chicken.']}]},
#    {'phrase': 'broccoli beef',
#     'reviews': [{'review_id': '7397',
#       'sentences': ["We got chicken Fried rice (it's a generous plate), crab cigars (like egg rolls), broccoli beef, bbq spare ribs, spicy wontons, calamari and a couple more."]},
#      {'review_id': '7413',
#       'sentences': ["I came into W's and had broccoli beef, garlic noddles, and the general chicken which were incredibly delicious."]},
#      {'review_id': '7668',
#       'sentences': ["The calamari Rick suggested was good but we decided to do some of the $8 meals on Saturday evening and the broccoli beef was the best we've ever had!"]}]},
#    {'phrase': 'hour prices',
#     'reviews': [{'review_id': '7616',
#       'sentences': ['We just love their happy hour prices and food selections.']},
#      {'review_id': '7509', 'sentences': ['Good happy hour prices!']},
#      {'review_id': '7385',
#       'sentences': ['Stopped in for Sen Hour (happy Hour prices) - no reservation, but we were seated immediately.']}]},
#    {'phrase': 'chow mein',
#     'reviews': [{'review_id': '7500',
#       'sentences': ['We ordered the cream cheese wontons, ahi poke, beef chow mein crispy, and sesame chicken.']},
#      {'review_id': '7502',
#       'sentences': ['The two of us were FULL after an entree and some rice and chow mein!']}]},
#    {'phrase': 'portion size',
#     'reviews': [{'review_id': '7619',
#       'sentences': ["I can't believe they have a $5 menu on Saturdays and Sundays for the ample portion size and the excellent quality of food."]},
#      {'review_id': '7519',
#       'sentences': ['At first I thought it was a tad pricey, but for the portion size, the price is totally worth it.']}]},
#    {'phrase': 'star review',
#     'reviews': [{'review_id': '7471',
#       'sentences': ["The reason why I didn't give it a 5 star review is because the only type of chicken they have is something called orange chicken with different toppings."]},
#      {'review_id': '7380',
#       'sentences': ['I would like to give a 5 star review to Oscar.']}]},
#    {'phrase': 'ice cream',
#     'reviews': [{'review_id': '7402',
#       'sentences': ['Have kids they have a kids menu with chicken nuggets to chow noodles and even vanilla ice cream for dessert.']},
#      {'review_id': '7585',
#       'sentences': ['What put this at 5 stars was the banana spring roll with house made banana ice cream OMG the bomb']}]},
#    {'phrase': 'chicken lunch',
#     'reviews': [{'review_id': '7433',
#       'sentences': ['I had their orange chicken lunch plate with chowmein instead of rice.']},
#      {'review_id': '7438',
#       'sentences': ['Orange chicken, sesame chicken, garlic chicken lunch plates ALL superb.']}]},
#    {'phrase': 'bar area',
#     'reviews': [{'review_id': '7431',
#       'sentences': ["Nice bar area with TV's showing sports."]},
#      {'review_id': '7376',
#       'sentences': ['Arrived 6PM and the two of us were seated in the bar area.']}]},
#    {'phrase': 'crispy noodles',
#     'reviews': [{'review_id': '7544',
#       'sentences': ['Excellent food - try the crispy noodles with chicken and beef skewers!']},
#      {'review_id': '7462',
#       'sentences': ["NJ meets Cali....very very good....nj spareribs portions are larger but these in Cali fall off the bone...not to saucy....cooked well....their crispy noodles are very good as well.....we also ordered wonton soup...the sliced ginger in the soup was amazing....very good..I will ask for that in NJ...beef chow fun...#1 noodles are homemade...you can't get that unless you are in Chinatown.....very friendly staff.....wine very good..."]}]},
#    {'phrase': 'chinese bistro',
#     'reviews': [{'review_id': '7657',
#       'sentences': ['If only this delicious Chinese Bistro would move to Huntington Beach!']},
#      {'review_id': '7457',
#       'sentences': ['This place is the best Chinese bistro food ever!!!']}]},
#    {'phrase': 'birthday girl',
#     'reviews': [{'review_id': '7630',
#       'sentences': ["Also, they brought 3 dishes out, then brought 2 more 5 minutes later, and then finally brought the birthday girl's dinner 10 minutes later."]},
#      {'review_id': '7449',
#       'sentences': ['Forgot to order a cup of soup for the birthday girl.']}]},
#    {'phrase': 'food quality',
#     'reviews': [{'review_id': '7472',
#       'sentences': ['The food quality is way better.']},
#      {'review_id': '7491',
#       'sentences': ['There are 3 things that I normally look for in a good restaurant, good service ,scenery , and food quality.']}]},
#    {'phrase': 'beef chow',
#     'reviews': [{'review_id': '7500',
#       'sentences': ['We ordered the cream cheese wontons, ahi poke, beef chow mein crispy, and sesame chicken.']},
#      {'review_id': '7462',
#       'sentences': ["NJ meets Cali....very very good....nj spareribs portions are larger but these in Cali fall off the bone...not to saucy....cooked well....their crispy noodles are very good as well.....we also ordered wonton soup...the sliced ginger in the soup was amazing....very good..I will ask for that in NJ...beef chow fun...#1 noodles are homemade...you can't get that unless you are in Chinatown.....very friendly staff.....wine very good..."]}]},
#    {'phrase': 'yelp review',
#     'reviews': [{'review_id': '7444',
# ...
#      {'review_id': '5562',
#       'sentences': ['If you happen to arrive during their, the employees, lunch time you will get sluggish or even lack there of service.']}]},
#    {'phrase': 'pork chop',
#     'reviews': [{'review_id': '5682',
#       'sentences': ['I usually go for the yang chow fried rice, some fried noodles, steamed chicken in ginger, salt and pepper shrimp, and pork chop in spicy salt.']},
#      {'review_id': '5531',
#       'sentences': ['I got the fried calamari, fried pork chop, and xa xiu bbq (red sauce) pork with half rice and half noodles for barely $5!']}]},
#    {'phrase': 'sum places',
#     'reviews': [{'review_id': '5683',
#       'sentences': ["They had coarsely shredded wild mushrooms inside, which showed an attention to detail in cheap dim sum places that you don't see very often."]},
#      {'review_id': '5704',
#       'sentences': ["I'm not a fan of some of the dim sum places in Chinatown (I prefer places in the San Gabriel Valley, way more legit)."]}]},
#    {'phrase': 'pepper shrimp',
#     'reviews': [{'review_id': '5682',
#       'sentences': ['I usually go for the yang chow fried rice, some fried noodles, steamed chicken in ginger, salt and pepper shrimp, and pork chop in spicy salt.']},
#      {'review_id': '5639',
#       'sentences': ['I still like their salt and pepper shrimp, but their fried squid, sauteed sole, and pan fried noodles were all a miss.']}]},
#    {'phrase': 'ord street',
#     'reviews': [{'review_id': '5720',
#       'sentences': ['First of all the ABC Seafood Restaurant I went to was on Ord Street in Chinatown.']},
#      {'review_id': '5679',
#       'sentences': ['Cafeteria style store to get Chinese food to go is located on Ord Street.']}]},
#    {'phrase': 'har gow',
#     'reviews': [{'review_id': '5540',
#       'sentences': ['We only ordered the friend Sole whole fish, eggplant with ground pork and beef with black bean sauce chow fun + 4 dim sum plates (Har gow, sel my, cha sel bow, and some stuffed pastry my dad wanted) ... and it was really pretty good.',
#        'The dim sum was $2.80 for the har gow (shrimp) and a lesser amount for the other dishes!',
#        'In fact it was so good we got THREE fried Sole fishes plus another har gow to GO!']},
#      {'review_id': '5512',
#       'sentences': ['The food is pretty fresh and I am in love with the usual items I get: har gow and siu mai!']}]},
#    {'phrase': 'los angeles',
#     'reviews': [{'review_id': '5658',
#       'sentences': ["When I'm in the mood for Dim Sum I go to ABC Seafood, in Chinatown, Los Angeles."]},
#      {'review_id': '5624',
#       'sentences': ['I routine come here whenever I work in Los Angeles.']}]},
#    {'phrase': 'style steak',
#     'reviews': [{'review_id': '5560',
#       'sentences': ['Their french style steak is super tender!!']},
#      {'review_id': '5569',
#       'sentences': ['Deep fried squid with spicy salt, chow mein, French style steak = deliciousness!']}]},
#    {'phrase': 'sum fix',
#     'reviews': [{'review_id': '5644',
#       'sentences': ["My family has been coming to this place for a very long time to get our Dim Sum fix and I'm sad to say that it's seen it's glory days come and go."]},
#      {'review_id': '5604',
#       'sentences': ["If you're in LA and you need a dim sum fix in Chinatown this is the best place to go for the value."]}]},
#    {'phrase': 'sui mai',
#     'reviews': [{'review_id': '5523',
#       'sentences': ['The chicken was just what I needed and the sui mai were big meaty delicious, and with five in an order, was probably a bit heavy for a "light lunch," but I\'m not complaining.']},
#      {'review_id': '5663',
#       'sentences': ['We ordered Sui Mai and stuffed bean curd skin which were both greasy.']}]},
#    {'phrase': 'take-out section',
#     'reviews': [{'review_id': '5552',
#       'sentences': ['The date of this review is October 18, 2014 and only for their take-out section of the restaurant.']},
#      {'review_id': '5703',
#       'sentences': ["I haven't had dinner in the dining room - but have gotten the food to-go in their take-out section (which is on the side of the restaurant)."]}]},
#    {'phrase': 'siu mai',
#     'reviews': [{'review_id': '5512',
#       'sentences': ['The food is pretty fresh and I am in love with the usual items I get: har gow and siu mai!']},
#      {'review_id': '5523',
#       'sentences': ['I swung in today while I was walking around Chinatown and grabbed an order of siu mai and a small chicken teriyaki to go.']}]},
#    {'phrase': 'par experiences',
#     'reviews': [{'review_id': '5629',
#       'sentences': ['Because I have always had sub par experiences.']},
#      {'review_id': '5626',
#       'sentences': ['Because I have always had sub par experiences.']}]},
#    {'phrase': 'chinese restaurants',
#     'reviews': [{'review_id': '5524',
#       'sentences': ["The restaurant isn't as big as some other big Chinese restaurants are but I didn't have to wait for a table anyway."]},
#      {'review_id': '5623',
#       'sentences': ["I've only come here for dinner, and the pricing is similar to the Chinese restaurants in Monterey Park."]}]},
#    {'phrase': 'star post',
#     'reviews': [{'review_id': '5517',
#       'sentences': ["this ain't a ONE STAR post, it's a ZERO STAR post.",
#        "this ain't a ONE STAR post, it's a ZERO STAR post."]},
#      {'review_id': '5516',
#       'sentences': ['"not a one star post, but a zero post."']}]},
#    {'phrase': 'egg rolls',
#     'reviews': [{'review_id': '5730',
#       'sentences': ['Must haves include shrimp and banana egg rolls, frosted baked bbq pork buns.']},
#      {'review_id': '5729',
#       'sentences': ['As Lawrence said, the pork buns and shrimp/bannana egg rolls are stand outs.']}]},
#    {'phrase': 'nothing fancy',
#     'reviews': [{'review_id': '5588',
#       'sentences': ["This is nothing fancy but the prices aren't high either."]},
#      {'review_id': '5575',
#       'sentences': ["I was really skeptical when I first walked in, it's really nothing fancy to look at, but was blown away!"]}]},
#    {'phrase': 'combo b',
#     'reviews': [{'review_id': '5549',
#       'sentences': ['They have their combos that I always get (combo B).']},
#      {'review_id': '5530',
#       'sentences': ['I always order Combo B with rice or chow mein and two items.']}]},
#    {'phrase': 'super cheap',
#     'reviews': [{'review_id': '5665',
#       'sentences': ['Absolute hole in the wall place that kinda looks sketchy, but super cheap and tasty dim sum that is not sketchy at all!!']},
#      {'review_id': '5679', 'sentences': ['Super cheap.']}]},
#    {'phrase': 'quality food',
#     'reviews': [{'review_id': '5604',
#       'sentences': ['Great prices and quality food.']},
#      {'review_id': '5607',
#       'sentences': ['the cheapest combo deals you can find anywhere, very decent quality food too (the chow fun flat rice noodle is slightly firm and not too oily...just the way i like it!)']}]},
#    {'phrase': 'lunch specials',
#     'reviews': [{'review_id': '5540',
#       'sentences': ['They have LUNCH SPECIALS on the weekend!']},
#      {'review_id': '5633',
#       'sentences': ['They have lunch specials for only a couple of bucks!']}]},
#    {'phrase': 'cbs seafood',
#     'reviews': [{'review_id': '5496',
#       'sentences': ["They have an actual full-sized dine-in restaurant as well, which is in a separate building on Spring Street and if I recall correctly (Yelpers can correct me, if I'm mistaken), it is in the building immediately behind this one and should be right next door to CBS Seafood restaurant so don't get these two confused."]},
#      {'review_id': '5707',
#       'sentences': ['A Cantonese style seafood restaurant similar to CBS Seafood across the street, only smaller and a little shoddier in atmosphere.']}]},
#    {'phrase': 'family style',
#     'reviews': [{'review_id': '5479',
#       'sentences': ["Give this place a chance if you're looking for some old fashion family style Chinese food~"]},
#      {'review_id': '5639',
#       'sentences': ["While their prices are still quite inexpensive for family style entrees, the food just doesn't measure up."]}]},
#    {'phrase': 'sum carts',
#     'reviews': [{'review_id': '5621',
#       'sentences': ['haha Anyway sadly they did not have the dim sum carts anymore....']},
#      {'review_id': '5723',
#       'sentences': ['Nor is the omnipresent smell of Sterno to fuel the ratty dim sum carts a major attraction as I found that I was getting nauseated and there was no air movement in the place to circulate the smell.']}]},
#    {'phrase': 'school chinese',
#     'reviews': [{'review_id': '5715',
#       'sentences': ["It's very old school chinese restaurant."]}]},
#    {'phrase': 'oddball servers',
#     'reviews': [{'review_id': '5685',
#       'sentences': ['Sure, ABC is dingy, has some oddball servers, and no longer has carts but these are the things that make me love it--that and the delicious, cheap dim sum.']}]},
#    {'phrase': 'pavilion closed..',
#     'reviews': [{'review_id': '5545',
#       'sentences': ['I started going to ABC since Empress Pavilion closed.. Food is good but the service is HORRIBLE!!!']}]},
#    {'phrase': 'xiu bbq',
#     'reviews': [{'review_id': '5531',
#       'sentences': ['I got the fried calamari, fried pork chop, and xa xiu bbq (red sauce) pork with half rice and half noodles for barely $5!']}]},
#    {'phrase': 'afternoon snacks',
#     'reviews': [{'review_id': '5592',
#       'sentences': ['These Bun Buns are a weekly addiction and they make for great afternoon snacks.']}]},
#    {'phrase': 'half stars',
#     'reviews': [{'review_id': '5583',
#       'sentences': ["Giving this place 2.5 stars, but since there's no half stars, I'll settle for 2."]}]},
#    {'phrase': 'sponge cake',
#     'reviews': [{'review_id': '5482',
#       'sentences': ['$63 for 6 dim sum plates, a half duck, pan fried noodles, and an order of sponge cake.']}]},
#    {'phrase': 'store owner',
#     'reviews': [{'review_id': '5599',
#       'sentences': ['I took my family to visit Olvera St and then decided to head to chinatown and eat at one of their restaurants recommend it by one store owner.']}]},
#    {'phrase': 'panda express',
#     'reviews': [{'review_id': '5602',
#       'sentences': ['After walking into this place, it appears that there is two sides: A fast food walk-in order-to-go Panda Express type of place and an actual sit down and order side.']}]},
#    {'phrase': 'beef french',
#     'reviews': [{'review_id': '5550',
#       'sentences': ['The filet of beef French style was like s tender peppery delight.']}]},
#    {'phrase': 'movie marathon',
#     'reviews': [{'review_id': '5519',
#       'sentences': ["I'd rather sit through a Zack Snyder movie marathon than eat at this fucking place again."]}]},
#    {'phrase': 'star rating',
#     'reviews': [{'review_id': '5713',
#       'sentences': ['This place gets a three star rating because after buying 4 dim sum dishes, we walked away with a bill for $22 bucks.']}]},
#    {'phrase': 'place ive',
#     'reviews': [{'review_id': '5492',
#       'sentences': ['Same as those chinese food place ive been going to.']}]},
#    {'phrase': 'closed.. food',
#     'reviews': [{'review_id': '5545',
#       'sentences': ['I started going to ABC since Empress Pavilion closed.. Food is good but the service is HORRIBLE!!!']}]},
#    {'phrase': 'flower soup',
#     'reviews': [{'review_id': '5521',
#       'sentences': ['also got the egg flower soup...']}]},
#    {'phrase': 'yelp rating',
#     'reviews': [{'review_id': '5519',
#       'sentences': ['I took a chance after seen the decent Yelp rating, but regretted it.']}]},
#    {'phrase': 'decent chinese',
#     'reviews': [{'review_id': '5490', 'sentences': ['Decent chinese food.']}]},
#    {'phrase': 'trip home',
#     'reviews': [{'review_id': '5535',
#       'sentences': ["I ask for it whole or half, and have to insist they don't whack it into chunks, because they will then ladle sauce on it, and it goes soggy on the trip home."]}]},
#    {'phrase': 'party trays',
#     'reviews': [{'review_id': '5513',
#       'sentences': ['We recently ordered party trays for our party last Saturday.']}]},
#    {'phrase': 'cheap tasty',
#     'reviews': [{'review_id': '5549',
#       'sentences': ['Check this place out for a cheap tasty meal!']}]},
#    {'phrase': 'taste fresh',
#     'reviews': [{'review_id': '5578',
#       'sentences': ['To me the food taste fresh and the service was great.']}]},
#    {'phrase': 'banana egg',
#     'reviews': [{'review_id': '5730',
#       'sentences': ['Must haves include shrimp and banana egg rolls, frosted baked bbq pork buns.']}]},
#    {'phrase': 'food taste',
#     'reviews': [{'review_id': '5578',
#       'sentences': ['To me the food taste fresh and the service was great.']}]},
#    {'phrase': 'broccoli w/',
#     'reviews': [{'review_id': '5630',
#       'sentences': ['We ordered War Wonton soup, House Special Pan Fried Noodles, Chinese Broccoli w/ Oyster Sauce, Mongolian Beef, and steamed rice.']}]},
#    {'phrase': 'sum category',
#     'reviews': [{'review_id': '5705',
#       'sentences': ["it's in the dim sum category, but i've never had dim sum here..."]}]},
#    {'phrase': 'santa barbara',
#     'reviews': [{'review_id': '5561',
#       'sentences': ['Have the fresh Santa Barbara Shrimp, hot sake, and fresh Crab in Black Bean Chilli sauce.']}]},
#    {'phrase': 'duck dish',
#     'reviews': [{'review_id': '5583',
#       'sentences': ['My roasted duck dish came out cold, as did the beef fried rice.']}]},
#    {'phrase': 'fave place',
#     'reviews': [{'review_id': '5480',
#       'sentences': ['Along with the aformentioned and Phillippe, one of my fave place in/around Chinatown.']}]},
#    {'phrase': 'wild mushrooms',
#     'reviews': [{'review_id': '5683',
#       'sentences': ["They had coarsely shredded wild mushrooms inside, which showed an attention to detail in cheap dim sum places that you don't see very often."]}]},
#    {'phrase': 'school joints',
#     'reviews': [{'review_id': '5500',
#       'sentences': ['This is definitely one of those old school joints of the day (see pic) with old school prices (see pic) we ordered a whole duck ($17) (see pic) vs the $9 for half.']}]},
#    {'phrase': 'omnipresent smell',
#     'reviews': [{'review_id': '5723',
#       'sentences': ['Nor is the omnipresent smell of Sterno to fuel the ratty dim sum carts a major attraction as I found that I was getting nauseated and there was no air movement in the place to circulate the smell.']}]},
#    {'phrase': 'cheap price',
#     'reviews': [{'review_id': '5555',
#       'sentences': ['I thought this was a good place, as the food tasted great for a cheap price, but I will never come here again as my friend spit out a COCKAROACH after taking a bite of his food!!']}]},
#    {'phrase': 'food restaurants',
#     'reviews': [{'review_id': '5708',
#       'sentences': ["Bland, basic food that I've had much better of in the 2 side item combo fast food restaurants."]}]},
#    {'phrase': 'bok choy',
#     'reviews': [{'review_id': '5640',
#       'sentences': ['My usual was the bbq pork and the thick greasy chow mein noodles with bok choy.']}]},
#    {'phrase': 'xa xiu',
#     'reviews': [{'review_id': '5531',
#       'sentences': ['I got the fried calamari, fried pork chop, and xa xiu bbq (red sauce) pork with half rice and half noodles for barely $5!']}]},
#    {'phrase': 'steam tables',
#     'reviews': [{'review_id': '5703',
#       'sentences': ['You can buy some dim sum items (they have steam tables), roasted duck and other BBQ meats, and also fast-food style food.']}]},
#    {'phrase': 'style restaurant',
#     'reviews': [{'review_id': '5495',
#       'sentences': ['This is a Cantonese style restaurant, which makes me feel all warm and fuzzy.']}]},
#    {'phrase': 'sum spot',
#     'reviews': [{'review_id': '5716',
#       'sentences': ['This spot is the CHEAPEST dim sum spot in all of Downtown China town.']}]},
#    {'phrase': 'family feast',
#     'reviews': [{'review_id': '5674',
#       'sentences': ['got to try their dim sum, cod fish, duck, steamed veggies, hot & sour soup....... all were good to eat.. service was nice, inside seemed alright.. but yeah.. great for a family feast here!']}]}]}]

# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Dec  2 14:32:59 2017

@author: hasee
"""
from textblob import TextBlob
import json
d = {}
with open('groupby_resuaurant_phrase2Grams_review.json') as json_data:
    d=json.load(json_data)
    
for restaurant in d[0:5]:
    print()
    print(restaurant['restaurantId'])
    likes=[]
    dislikes=[]
    for topword in restaurant['top-none-phrases'][0:10]:
        
        scoreword=0
#        print(topword['phrase'])
        for reviews in topword['reviews']:
            countse=0
            scorese=0;
            for sentence in reviews['sentences']:
                sentence=sentence.replace('chicken','beef')
                blob = TextBlob(sentence)
                blob.tags
                blob.noun_phrases
                ns=blob.sentences[0].sentiment.polarity
                scorese+=ns
#                print(sentence)
#                print(ns)
                countse+=1;
            scoreword+=scorese/countse
        result_word_score_avg=scoreword/len(topword['reviews'])
        if result_word_score_avg>0:
            likes.append(topword['phrase'])
        else:
            dislikes.append(topword['phrase'])
#        print(result_word_score_avg)
    print('What the Guests loved Most: ')
    for like in likes:
        print(like)
    print()
    print('What nedd to be improved: ')
    for dislike in dislikes:
        print(dislike)
    print()
    print()
# Out:
# chinese_6
# What the Guests loved Most:
# chinese food
# egg rolls
# lunch specials
# chow mein
# chinese restaurant
# orange chicken
# chinese place
# walnut shrimp
# cream cheese
#
# What nedd to be improved:
# customer service
#
#
#
# chinese_22
# What the Guests loved Most:
# chinese food
# orange chicken
# chow mein
# egg rolls
# walnut shrimp
# egg roll
# egg drop
# drop soup
# panda express
#
# What nedd to be improved:
# customer service
#
#
#
# chinese_27
# What the Guests loved Most:
# happy hour
# chinese food
# south bay
# orange chicken
# cream cheese
# chinese restaurant
# china bistro
# cheese wontons
# zen hour
# spring rolls
#
# What nedd to be improved:
#
#
#
# chinese_0
# What the Guests loved Most:
# chinese food
# orange chicken
# eagle rock
# kung pao
# chinese restaurant
# pao chicken
# lo mein
# customer service
# egg roll
# pork dumplings
#
# What nedd to be improved:
#
#
#
# chinese_2
# What the Guests loved Most:
# dim sum
# chinese food
# pork buns
# bbq pork
# sesame balls
# chow fun
# customer service
# chow mein
# wonton soup
# shu mai
#
# What nedd to be improved:
